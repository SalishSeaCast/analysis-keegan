# %% [markdown]
# A notebook which contains an evaluation of the SalishSeaCast model within PugetSound using all of the Washington Department of Ecology CTD data collected between 2007 and 2019. More specifically, it takes observed temperature, salinity, and chlorophyll concentrations collected by a CTD and compares them to the model output. This evaluation includes scatter plots and 2d histograms visualizing the similarity of observed and model data as well as tables of evaluation statistics.

# %%
import sys
sys.path.append('/ocean/kflanaga/MEOPAR/analysis-keegan/notebooks/Tools')

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import netCDF4 as nc
import datetime as dt
from salishsea_tools import evaltools as et, viz_tools
import gsw 
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import matplotlib.dates as mdates
import cmocean as cmo
import scipy.interpolate as sinterp
import pickle
import cmocean
import json
import f90nml
import Keegan_eval_tools as ket
from collections import OrderedDict
from matplotlib.colors import LogNorm

fs=16
mpl.rc('xtick', labelsize=fs)
mpl.rc('ytick', labelsize=fs)
mpl.rc('legend', fontsize=fs)
mpl.rc('axes', titlesize=fs)
mpl.rc('axes', labelsize=fs)
mpl.rc('figure', titlesize=fs)
mpl.rc('font', size=fs)
mpl.rc('font', family='sans-serif', weight='normal', style='normal')

import warnings
#warnings.filterwarnings('ignore')
from IPython.display import Markdown, display

# %matplotlib inline

# %% [raw]
# from IPython.display import HTML
#
# HTML('''<script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
years=range(2007,2020)
modelversion='nowcast-green.201905'
PATH= '/results2/SalishSea/nowcast-green.201905/'
datadir='/ocean/kflanaga/MEOPAR/savedData/WADE_CTD_pickles'

# %%
display(Markdown('''## All years summary'''))
# Out:
# ## All years summary

# %%
display(Markdown('''### Model output: '''+ PATH))
# Out:
# ### Model output: /results2/SalishSea/nowcast-green.201905/

# %% [markdown]
# ## Yearly model-data comparisons of chlorophyll, temperature and salinity between 201905 runs and CTD observations

# %%
##### Loading in pickle file data
dictbot=dict()

for Y in years:
    with open(os.path.join(datadir,f'data_CTD_{modelversion}_{Y}.pkl'),'rb') as hh:
        dictbot[Y]=pickle.load(hh)
    
data_CTD=pd.concat(dictbot.values(), ignore_index=True)

# %%
#Adding extra columns to assist in analysis.

Chl_to_N=1.8
data_CTD['log_Chl']=ket.logt(data_CTD['Chl'])
data_CTD['log_mod_diatoms']=ket.logt(data_CTD['mod_diatoms']*Chl_to_N)
data_CTD['log_mod_ciliates']=ket.logt(data_CTD['mod_ciliates']*Chl_to_N)
data_CTD['log_mod_flagellates']=ket.logt(data_CTD['mod_flagellates']*Chl_to_N)
data_CTD['mod_Chl']=((data_CTD['mod_diatoms']*Chl_to_N)+(data_CTD['mod_ciliates']*Chl_to_N)+(data_CTD['mod_flagellates']*Chl_to_N))
data_CTD['log_mod_Chl']=ket.logt((data_CTD['mod_diatoms']*Chl_to_N)+(data_CTD['mod_ciliates']*Chl_to_N)+(data_CTD['mod_flagellates']*Chl_to_N))

# defning a dictionary that brakes the data down by individual stations
datstat_CTD=dict()
for ind, istation in enumerate(data_CTD.Station.unique()):
    datstat_CTD[istation]=data_CTD.loc[data_CTD.Station == istation]

datreg_CTD=dict()
for iregion in data_CTD.Basin.unique():
    datreg_CTD[iregion] = data_CTD.loc[data_CTD.Basin==iregion]
    
datyear_CTD=dict()
for iyear in range(2008,2020):
    datyear_CTD[iyear] = data_CTD.loc[data_CTD.Year==iyear]
# Out:
# /home/kflanaga/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Creating seperate dataframes for each season (includes only data above 15 metre depth.)
iz=(data_CTD.Z<15)
DJFd=dict()
MAMd=dict()
JJAd=dict()
SONd=dict()
for i in range(2008,2020):
    DJFd[i]=data_CTD.loc[iz&(data_CTD.dtUTC>=dt.datetime(i-1,12,1))&(data_CTD.dtUTC<=dt.datetime(i,3,1)),:]
    MAMd[i]=data_CTD.loc[iz&(data_CTD.dtUTC<=dt.datetime(i,6,1))&(data_CTD.dtUTC>dt.datetime(i,3,1)),:]
    JJAd[i]=data_CTD.loc[iz&(data_CTD.dtUTC<=dt.datetime(i,9,1))&(data_CTD.dtUTC>dt.datetime(i,6,1)),:]
    SONd[i]=data_CTD.loc[iz&(data_CTD.dtUTC>dt.datetime(i,9,1))&(data_CTD.dtUTC<=dt.datetime(i,11,30)),:]
DJF_CTD=pd.concat(DJFd.values(), ignore_index=True)
MAM_CTD=pd.concat(MAMd.values(), ignore_index=True)
JJA_CTD=pd.concat(JJAd.values(), ignore_index=True)
SON_CTD=pd.concat(SONd.values(), ignore_index=True)

# %%
### These groupings will be used to calculate statistics. The keys are labels and
### the values are corresponding dataframe views
statsubs_CTD=OrderedDict({'z < 15 m':data_CTD.loc[data_CTD.Z<15],
                      '15 m < z < 22 m':data_CTD.loc[(data_CTD.Z>=15)&(data_CTD.Z<22)],
                      'z >= 22 m':data_CTD.loc[data_CTD.Z>=22],
                      'z > 50 m':data_CTD.loc[data_CTD.Z>50],
                      'all':data_CTD,
                      'z < 15 m, DJF':DJF_CTD,
                      'z < 15 m, MAM':MAM_CTD,
                      'z < 15 m, JJA':JJA_CTD,
                      'z < 15 m, SON': SON_CTD})

# %%
#Creating a list of regions so that they appear in graphs and tables in
#My preferred order
regions=['Admiralty Inlet','Main Basin','South Basin','Hood Canal Basin',
         'Whidbey Basin','Strait of Georgia','Strait of Juan de Fuca']

#Creating dictionaries of regions. 
for iregion in regions:
    statsubs_CTD[iregion]=datreg_CTD[iregion]
statsubs_CTD.keys()

yearsubs_CTD=OrderedDict({
                      })
for iyear in range(2008,2020):
    yearsubs_CTD[iyear]=datyear_CTD[iyear]
yearsubs_CTD.keys()
# Out:
# odict_keys([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %% [markdown]
# ## Map of observation locations in each basin

# %%
fig, ax = plt.subplots(1,1,figsize = (6,6))
with nc.Dataset('/data/vdo/MEOPAR/NEMO-forcing/grid/bathymetry_201702.nc') as grid:
    viz_tools.plot_coastline(ax, grid, coords = 'map',isobath=.1)
colors=('blue','green','firebrick','darkorange','darkviolet','fuchsia',
        'royalblue','darkgoldenrod','mediumspringgreen','deepskyblue')
for ind, iregion in enumerate(data_CTD.Basin.unique()):
    ax.plot(datreg_CTD[iregion]['Lon'], datreg_CTD[iregion]['Lat'],'.',
            color = colors[ind], label=iregion)
ax.set_ylim(47, 49)
ax.legend(bbox_to_anchor=[1,.6,0,0])
ax.set_xlim(-124, -122);
ax.set_title('Observation Locations');

# %% [markdown]
# # Absolute Salinity (g/kg)

# %% [markdown]
# ### Table containing evaluation statistics for relevant subsets

# %%
def displayStats(statdict,level='Subset',suborder=None):
    # stats dict starting from variable level
    cols={'Subset':('Subset','Metric',''),
          'Variable':('Variable','Subset','Metric',''),
          'Year':('Year','Variable','Subset','Metric','')}
    ind={'Subset':['Order','Subset','Metric'],
         'Variable':['Variable','Order','Subset','Metric'],
         'Year':['Variable','Subset','Metric']}
    pcols={'Subset':['Metric'],
           'Variable':['Metric'],
           'Year':['Year','Metric']}
    allrows=et._flatten_nested_dict(statdict)
    tdf=pd.DataFrame(allrows,columns=cols[level])
    if suborder is not None:
        subD={suborder[ii]: ii for ii in range(0,len(suborder))}
        tdf['Order']=[subD[tdf['Subset'][ii]] for ii in range(0,len(tdf['Subset']))]
    tdf.set_index(ind[level],inplace=True)
    tbl=pd.pivot_table(tdf,index=ind[level][:-1],columns=pcols[level]).rename_axis(index={'Order':None},columns={'Metric':None})
    cols2=[('','mmean'),('','Bias'),('','RMSE'),('','WSS'),('','N')]
    tbl=tbl[cols2]
    tbl=tbl.style.format({
    ('','N'): '{:.0f}'.format,
    ('','mmean'):'{:.3f}'.format,
    ('','Bias'):'{:.3f}'.format,
    ('','WSS'):'{:.3f}'.format,
    ('','RMSE'):'{:.3f}'.format})
    return tbl,tdf

# %%
# Setting Variable for Temperature. 
obsvar='SA'
modvar='mod_vosaline'
regions=data_CTD.Basin.unique()

# %%
statsDict_CTSA=dict()
statsDict_CTSA['SA']=OrderedDict()
for isub in statsubs_CTD:
    print(isub)
    statsDict_CTSA['SA'][isub]=dict()
    var=statsDict_CTSA['SA'][isub]
    var['N'],var['mmean'],omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]],
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=displayStats(statsDict_CTSA['SA'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# z < 15 m
# 15 m < z < 22 m
# z >= 22 m
# z > 50 m
# all
# z < 15 m, DJF
# z < 15 m, MAM
# z < 15 m, JJA
# z < 15 m, SON
# Admiralty Inlet
# Main Basin
# South Basin
# Hood Canal Basin
# Whidbey Basin
# Strait of Georgia
# Strait of Juan de Fuca
# <style  type="text/css" >
# </style><table id="T_e27d0298_a796_11eb_9131_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=5></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >mmean</th>        <th class="col_heading level1 col1" >Bias</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>        <th class="col_heading level1 col4" >N</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row0_col0" class="data row0 col0" >28.518</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row0_col1" class="data row0 col1" >-0.465</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row0_col2" class="data row0 col2" >1.389</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row0_col3" class="data row0 col3" >0.867</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row0_col4" class="data row0 col4" >96087</td>
#             </tr>
#             <tr>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row1_col0" class="data row1 col0" >29.467</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row1_col1" class="data row1 col1" >-0.333</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row1_col2" class="data row1 col2" >0.648</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row1_col3" class="data row1 col3" >0.878</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row1_col4" class="data row1 col4" >43202</td>
#             </tr>
#             <tr>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row2_col0" class="data row2 col0" >30.277</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row2_col1" class="data row2 col1" >-0.093</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row2_col2" class="data row2 col2" >0.491</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row2_col3" class="data row2 col3" >0.947</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row2_col4" class="data row2 col4" >495313</td>
#             </tr>
#             <tr>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row3_col0" class="data row3 col0" >30.481</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row3_col1" class="data row3 col1" >-0.042</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row3_col2" class="data row3 col2" >0.474</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row3_col3" class="data row3 col3" >0.952</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row3_col4" class="data row3 col4" >345419</td>
#             </tr>
#             <tr>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row4_col0" class="data row4 col0" >29.955</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row4_col1" class="data row4 col1" >-0.166</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row4_col2" class="data row4 col2" >0.713</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row4_col3" class="data row4 col3" >0.929</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row4_col4" class="data row4 col4" >634602</td>
#             </tr>
#             <tr>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row5_col0" class="data row5 col0" >28.531</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row5_col1" class="data row5 col1" >-0.135</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row5_col2" class="data row5 col2" >1.479</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row5_col3" class="data row5 col3" >0.864</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row5_col4" class="data row5 col4" >18415</td>
#             </tr>
#             <tr>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row6_col0" class="data row6 col0" >28.255</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row6_col1" class="data row6 col1" >-0.313</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row6_col2" class="data row6 col2" >1.293</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row6_col3" class="data row6 col3" >0.884</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row6_col4" class="data row6 col4" >23867</td>
#             </tr>
#             <tr>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row7_col0" class="data row7 col0" >28.099</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row7_col1" class="data row7 col1" >-0.795</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row7_col2" class="data row7 col2" >1.489</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row7_col3" class="data row7 col3" >0.845</td>
#                         <td id="T_e27d0298_a796_11eb_9131_10c37b4d98e4row7_col4" class="data row7 col4" >24183</td>
#             </tr>
#             <tr>
#                         <th id="T_e27d0298_a796_11eb_9131_10c37b4d98e4level0_row8" class="row_heading level0 row8" >

# %% [markdown]
# ### Model vs Observed comparisons by depth and region

# %%
lims=(0,40)

fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('S$_A$ (g kg$^{-1}$) By Depth')

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('S$_A$ (g kg$^{-1}$) By Region');

# %% [markdown]
# ### 2D Histogram of model vs observed

# %%
fig, ax = plt.subplots(1,3,figsize= (17,5))
obsvar='SA'
modvar='mod_vosaline'
ps = ket.hist2d(ax[0],fig,data_CTD,obsvar,modvar,lims,fontsize=18)
ax[0].set_title('S$_A$ (g kg$^{-1}$)',fontsize=18)
ps = ket.hist2d(ax[2],fig,data_CTD[data_CTD.Basin=='South Basin'],obsvar,modvar,lims,fontsize=18)
ax[2].set_title('S$_A$ (g kg$^{-1}$) In South Basin',fontsize=18)
obsvar='CT'
modvar='mod_votemper'
ps = ket.hist2d(ax[1],fig,data_CTD,obsvar,modvar,lims,fontsize=18)
ax[1].set_title('S$_A$ (g kg$^{-1}$)',fontsize=18)
# Out:
# Text(0.5, 1.0, 'S$_A$ (g kg$^{-1}$)')

# %% [markdown]
# ### 2d histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims,fontsize=18)
ax[0][0].set_title('S$_A$ (g kg$^{-1}$) In South Basin',fontsize=18)
ax[0][1].set_title('S$_A$ (g kg$^{-1}$) In Main Basin',fontsize=18)
# Out:
# Text(0.5, 1.0, 'S$_A$ (g kg$^{-1}$) In Main Basin')

# %% [markdown]
# ### Model vs observed comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (18,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('Modeled Salinity (g/kg)')
        ax[i][j].set_xlabel('Observed Salinity (g/kg)')

# %% [markdown]
# # Conservative Temperature

# %%
#Setting variables for temperature.
obsvar='CT'
modvar='mod_votemper'

# %% [markdown]
# ### Table containing evaluation statistics for relevant subsets

# %%
statsDict_CTSA['CT']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_CTSA['CT'][isub]=dict()
    var=statsDict_CTSA['CT'][isub]
    var['N'],var['mmean'],omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]],
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=displayStats(statsDict_CTSA['CT'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_e799eeef_a796_11eb_9154_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=5></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >mmean</th>        <th class="col_heading level1 col1" >Bias</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>        <th class="col_heading level1 col4" >N</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row0_col0" class="data row0 col0" >10.929</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row0_col1" class="data row0 col1" >0.091</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row0_col2" class="data row0 col2" >0.951</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row0_col3" class="data row0 col3" >0.961</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row0_col4" class="data row0 col4" >96086</td>
#             </tr>
#             <tr>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row1_col0" class="data row1 col0" >10.303</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row1_col1" class="data row1 col1" >-0.044</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row1_col2" class="data row1 col2" >0.536</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row1_col3" class="data row1 col3" >0.976</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row1_col4" class="data row1 col4" >43202</td>
#             </tr>
#             <tr>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row2_col0" class="data row2 col0" >9.740</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row2_col1" class="data row2 col1" >-0.148</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row2_col2" class="data row2 col2" >0.509</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row2_col3" class="data row2 col3" >0.972</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row2_col4" class="data row2 col4" >495313</td>
#             </tr>
#             <tr>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row3_col0" class="data row3 col0" >9.604</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row3_col1" class="data row3 col1" >-0.165</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row3_col2" class="data row3 col2" >0.501</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row3_col3" class="data row3 col3" >0.971</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row3_col4" class="data row3 col4" >345419</td>
#             </tr>
#             <tr>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row4_col0" class="data row4 col0" >9.958</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row4_col1" class="data row4 col1" >-0.105</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row4_col2" class="data row4 col2" >0.599</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row4_col3" class="data row4 col3" >0.971</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row4_col4" class="data row4 col4" >634601</td>
#             </tr>
#             <tr>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row5_col0" class="data row5 col0" >8.612</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row5_col1" class="data row5 col1" >-0.310</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row5_col2" class="data row5 col2" >0.697</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row5_col3" class="data row5 col3" >0.895</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row5_col4" class="data row5 col4" >18415</td>
#             </tr>
#             <tr>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row6_col0" class="data row6 col0" >9.404</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row6_col1" class="data row6 col1" >0.073</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row6_col2" class="data row6 col2" >0.607</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row6_col3" class="data row6 col3" >0.954</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row6_col4" class="data row6 col4" >23867</td>
#             </tr>
#             <tr>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row7_col0" class="data row7 col0" >13.115</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row7_col1" class="data row7 col1" >0.484</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row7_col2" class="data row7 col2" >1.446</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row7_col3" class="data row7 col3" >0.892</td>
#                         <td id="T_e799eeef_a796_11eb_9154_10c37b4d98e4row7_col4" class="data row7 col4" >24182</td>
#             </tr>
#             <tr>
#                         <th id="T_e799eeef_a796_11eb_9154_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>

# %% [markdown]
# ### Model vs Observed comparisons by depth and region

# %%
lims=(0,40)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('$\Theta$ ($^{\circ}$C) By Depth')

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('$\Theta$ ($^{\circ}$C) By Region');

# %% [markdown]
# ### 2D Histogram of model vs observed

# %%
fig, ax = plt.subplots(1,1,figsize= (12,8))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,lims,fontsize=18)
ax.set_title('$\Theta$ ($^{\circ}$C)',fontsize=18)
# Out:
# Text(0.5, 1.0, '$\\Theta$ ($^{\\circ}$C)')

# %% [markdown]
# ### 2d histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ### Model vs observed comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (18,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('Modeled Temperature (C$^o$)')
        ax[i][j].set_xlabel('Observed Salinity (C$^o$)')

# %% [markdown]
# ### Summary table of temperature and salinity evaluation statistics

# %%
tbl,tdf=displayStats(statsDict_CTSA,level='Variable',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=5></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >mmean</th>        <th class="col_heading level1 col1" >Bias</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>        <th class="col_heading level1 col4" >N</th>    </tr>    <tr>        <th class="index_name level0" >Variable</th>        <th class="index_name level1" ></th>        <th class="index_name level2" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level0_row0" class="row_heading level0 row0" rowspan=16>CT</th>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level1_row0" class="row_heading level1 row0" >0</th>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level2_row0" class="row_heading level2 row0" >z < 15 m</th>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row0_col0" class="data row0 col0" >10.929</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row0_col1" class="data row0 col1" >0.091</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row0_col2" class="data row0 col2" >0.951</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row0_col3" class="data row0 col3" >0.961</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row0_col4" class="data row0 col4" >96086</td>
#             </tr>
#             <tr>
#                                 <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level1_row1" class="row_heading level1 row1" >1</th>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level2_row1" class="row_heading level2 row1" >15 m < z < 22 m</th>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row1_col0" class="data row1 col0" >10.303</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row1_col1" class="data row1 col1" >-0.044</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row1_col2" class="data row1 col2" >0.536</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row1_col3" class="data row1 col3" >0.976</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row1_col4" class="data row1 col4" >43202</td>
#             </tr>
#             <tr>
#                                 <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level1_row2" class="row_heading level1 row2" >2</th>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level2_row2" class="row_heading level2 row2" >z >= 22 m</th>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row2_col0" class="data row2 col0" >9.740</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row2_col1" class="data row2 col1" >-0.148</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row2_col2" class="data row2 col2" >0.509</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row2_col3" class="data row2 col3" >0.972</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row2_col4" class="data row2 col4" >495313</td>
#             </tr>
#             <tr>
#                                 <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level1_row3" class="row_heading level1 row3" >3</th>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level2_row3" class="row_heading level2 row3" >z > 50 m</th>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row3_col0" class="data row3 col0" >9.604</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row3_col1" class="data row3 col1" >-0.165</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row3_col2" class="data row3 col2" >0.501</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row3_col3" class="data row3 col3" >0.971</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row3_col4" class="data row3 col4" >345419</td>
#             </tr>
#             <tr>
#                                 <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level1_row4" class="row_heading level1 row4" >4</th>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level2_row4" class="row_heading level2 row4" >all</th>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row4_col0" class="data row4 col0" >9.958</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row4_col1" class="data row4 col1" >-0.105</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row4_col2" class="data row4 col2" >0.599</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row4_col3" class="data row4 col3" >0.971</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row4_col4" class="data row4 col4" >634601</td>
#             </tr>
#             <tr>
#                                 <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level1_row5" class="row_heading level1 row5" >5</th>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level2_row5" class="row_heading level2 row5" >z < 15 m, DJF</th>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row5_col0" class="data row5 col0" >8.612</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row5_col1" class="data row5 col1" >-0.310</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row5_col2" class="data row5 col2" >0.697</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row5_col3" class="data row5 col3" >0.895</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row5_col4" class="data row5 col4" >18415</td>
#             </tr>
#             <tr>
#                                 <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level1_row6" class="row_heading level1 row6" >6</th>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level2_row6" class="row_heading level2 row6" >z < 15 m, MAM</th>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row6_col0" class="data row6 col0" >9.404</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row6_col1" class="data row6 col1" >0.073</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row6_col2" class="data row6 col2" >0.607</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row6_col3" class="data row6 col3" >0.954</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row6_col4" class="data row6 col4" >23867</td>
#             </tr>
#             <tr>
#                                 <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level1_row7" class="row_heading level1 row7" >7</th>
#                         <th id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4level2_row7" class="row_heading level2 row7" >z < 15 m, JJA</th>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row7_col0" class="data row7 col0" >13.115</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row7_col1" class="data row7 col1" >0.484</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row7_col2" class="data row7 col2" >1.446</td>
#                         <td id="T_ec5d635f_a796_11eb_8ed6_10c37b4d98e4row7_col3" clas

# %% [markdown]
# # Observed Chlorophyll vs Model Phytoplankton

# %%
#Setting variables for Chlorophyll.
obsvar='Chl'
modvar='mod_diatoms'

# %% [markdown]
# ## Model Diatoms vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets

# %%
statsDict_Chl=dict()
statsDict_Chl['Diatoms']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl['Diatoms'][isub]=dict()
    var=statsDict_Chl['Diatoms'][isub]
    var['N'],var['mmean'],omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=displayStats(statsDict_Chl['Diatoms'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=5></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >mmean</th>        <th class="col_heading level1 col1" >Bias</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>        <th class="col_heading level1 col4" >N</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row0_col0" class="data row0 col0" >0.540</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row0_col1" class="data row0 col1" >-4.524</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row0_col2" class="data row0 col2" >9.206</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row0_col3" class="data row0 col3" >0.338</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row0_col4" class="data row0 col4" >80209</td>
#             </tr>
#             <tr>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row1_col0" class="data row1 col0" >0.236</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row1_col1" class="data row1 col1" >-2.092</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row1_col2" class="data row1 col2" >3.530</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row1_col3" class="data row1 col3" >0.380</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row1_col4" class="data row1 col4" >36270</td>
#             </tr>
#             <tr>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row2_col0" class="data row2 col0" >0.070</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row2_col1" class="data row2 col1" >-1.047</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row2_col2" class="data row2 col2" >2.531</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row2_col3" class="data row2 col3" >0.213</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row2_col4" class="data row2 col4" >410861</td>
#             </tr>
#             <tr>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row3_col0" class="data row3 col0" >0.052</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row3_col1" class="data row3 col1" >-0.945</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row3_col2" class="data row3 col2" >2.684</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row3_col3" class="data row3 col3" >0.159</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row3_col4" class="data row3 col4" >286058</td>
#             </tr>
#             <tr>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row4_col0" class="data row4 col0" >0.153</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row4_col1" class="data row4 col1" >-1.648</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row4_col2" class="data row4 col2" >4.329</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row4_col3" class="data row4 col3" >0.250</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row4_col4" class="data row4 col4" >527340</td>
#             </tr>
#             <tr>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row5_col0" class="data row5 col0" >0.011</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row5_col1" class="data row5 col1" >-1.529</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row5_col2" class="data row5 col2" >2.970</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row5_col3" class="data row5 col3" >0.255</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row5_col4" class="data row5 col4" >15263</td>
#             </tr>
#             <tr>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row6_col0" class="data row6 col0" >0.966</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row6_col1" class="data row6 col1" >-5.194</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row6_col2" class="data row6 col2" >9.364</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row6_col3" class="data row6 col3" >0.405</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row6_col4" class="data row6 col4" >19372</td>
#             </tr>
#             <tr>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row7_col0" class="data row7 col0" >0.845</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row7_col1" class="data row7 col1" >-6.142</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row7_col2" class="data row7 col2" >11.751</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row7_col3" class="data row7 col3" >0.318</td>
#                         <td id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4row7_col4" class="data row7 col4" >20615</td>
#             </tr>
#             <tr>
#                         <th id="T_ec6b8350_a796_11eb_b278_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_diatoms'

lims=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('Diatoms vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')   

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('Diatoms vs Chlorophyll by Region');
ax[1].set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of model diatoms vs observed cholophyll

# %%
fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Diatoms vs Chlorophyl')
ax.set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2d histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ### Model vs observed comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (18,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ## Model Ciliates vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets.

# %%
obsvar='Chl'
modvar='mod_ciliates'

statsDict_Chl['Ciliates']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl['Ciliates'][isub]=dict()
    var=statsDict_Chl['Ciliates'][isub]
    var['N'],var['mmean'],omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=displayStats(statsDict_Chl['Ciliates'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=5></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >mmean</th>        <th class="col_heading level1 col1" >Bias</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>        <th class="col_heading level1 col4" >N</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row0_col0" class="data row0 col0" >0.170</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row0_col1" class="data row0 col1" >-4.894</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row0_col2" class="data row0 col2" >9.516</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row0_col3" class="data row0 col3" >0.329</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row0_col4" class="data row0 col4" >80209</td>
#             </tr>
#             <tr>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row1_col0" class="data row1 col0" >0.114</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row1_col1" class="data row1 col1" >-2.214</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row1_col2" class="data row1 col2" >3.691</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row1_col3" class="data row1 col3" >0.359</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row1_col4" class="data row1 col4" >36270</td>
#             </tr>
#             <tr>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row2_col0" class="data row2 col0" >0.067</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row2_col1" class="data row2 col1" >-1.051</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row2_col2" class="data row2 col2" >2.554</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row2_col3" class="data row2 col3" >0.205</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row2_col4" class="data row2 col4" >410861</td>
#             </tr>
#             <tr>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row3_col0" class="data row3 col0" >0.059</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row3_col1" class="data row3 col1" >-0.939</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row3_col2" class="data row3 col2" >2.694</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row3_col3" class="data row3 col3" >0.155</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row3_col4" class="data row3 col4" >286058</td>
#             </tr>
#             <tr>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row4_col0" class="data row4 col0" >0.086</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row4_col1" class="data row4 col1" >-1.715</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row4_col2" class="data row4 col2" >4.449</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row4_col3" class="data row4 col3" >0.223</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row4_col4" class="data row4 col4" >527340</td>
#             </tr>
#             <tr>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row5_col0" class="data row5 col0" >0.116</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row5_col1" class="data row5 col1" >-1.424</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row5_col2" class="data row5 col2" >2.912</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row5_col3" class="data row5 col3" >0.250</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row5_col4" class="data row5 col4" >15263</td>
#             </tr>
#             <tr>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row6_col0" class="data row6 col0" >0.167</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row6_col1" class="data row6 col1" >-5.992</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row6_col2" class="data row6 col2" >10.093</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row6_col3" class="data row6 col3" >0.385</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row6_col4" class="data row6 col4" >19372</td>
#             </tr>
#             <tr>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row7_col0" class="data row7 col0" >0.233</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row7_col1" class="data row7 col1" >-6.754</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row7_col2" class="data row7 col2" >12.041</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row7_col3" class="data row7 col3" >0.327</td>
#                         <td id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4row7_col4" class="data row7 col4" >20615</td>
#             </tr>
#             <tr>
#                         <th id="T_f1262b5f_a796_11eb_94ff_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_ciliates'

lims=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('Cliliates vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Model Ciliates (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')  

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('Cliliates vs Chlorophyll by Region')
ax[1].set_ylabel('log10[Model Ciliates (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of model ciliates vs observed chlorophyll

# %%
fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Cliliates vs Chlorophyll')
ax.set_ylabel('log10[Model Ciliates (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ## Model Ciliates vs observed Chlorophyll comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (16,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Modeled Cilliates (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ## Model Flagellates vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets.

# %%
obsvar='Chl'
modvar='mod_flagellates'

statsDict_Chl['Flagellates']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl['Flagellates'][isub]=dict()
    var=statsDict_Chl['Flagellates'][isub]
    var['N'],var['mmean'],omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=displayStats(statsDict_Chl['Flagellates'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=5></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >mmean</th>        <th class="col_heading level1 col1" >Bias</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>        <th class="col_heading level1 col4" >N</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row0_col0" class="data row0 col0" >0.444</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row0_col1" class="data row0 col1" >-4.620</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row0_col2" class="data row0 col2" >9.264</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row0_col3" class="data row0 col3" >0.335</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row0_col4" class="data row0 col4" >80209</td>
#             </tr>
#             <tr>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row1_col0" class="data row1 col0" >0.211</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row1_col1" class="data row1 col1" >-2.117</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row1_col2" class="data row1 col2" >3.601</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row1_col3" class="data row1 col3" >0.364</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row1_col4" class="data row1 col4" >36270</td>
#             </tr>
#             <tr>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row2_col0" class="data row2 col0" >0.075</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row2_col1" class="data row2 col1" >-1.043</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row2_col2" class="data row2 col2" >2.551</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row2_col3" class="data row2 col3" >0.206</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row2_col4" class="data row2 col4" >410861</td>
#             </tr>
#             <tr>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row3_col0" class="data row3 col0" >0.059</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row3_col1" class="data row3 col1" >-0.939</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row3_col2" class="data row3 col2" >2.696</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row3_col3" class="data row3 col3" >0.155</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row3_col4" class="data row3 col4" >286058</td>
#             </tr>
#             <tr>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row4_col0" class="data row4 col0" >0.140</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row4_col1" class="data row4 col1" >-1.661</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row4_col2" class="data row4 col2" >4.361</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row4_col3" class="data row4 col3" >0.237</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row4_col4" class="data row4 col4" >527340</td>
#             </tr>
#             <tr>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row5_col0" class="data row5 col0" >0.216</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row5_col1" class="data row5 col1" >-1.324</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row5_col2" class="data row5 col2" >2.855</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row5_col3" class="data row5 col3" >0.247</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row5_col4" class="data row5 col4" >15263</td>
#             </tr>
#             <tr>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row6_col0" class="data row6 col0" >0.269</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row6_col1" class="data row6 col1" >-5.891</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row6_col2" class="data row6 col2" >10.011</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row6_col3" class="data row6 col3" >0.385</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row6_col4" class="data row6 col4" >19372</td>
#             </tr>
#             <tr>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row7_col0" class="data row7 col0" >0.911</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row7_col1" class="data row7 col1" >-6.076</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row7_col2" class="data row7 col2" >11.519</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row7_col3" class="data row7 col3" >0.329</td>
#                         <td id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4row7_col4" class="data row7 col4" >20615</td>
#             </tr>
#             <tr>
#                         <th id="T_f574d0af_a796_11eb_a0c4_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_flagellates'

lims=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('Flagellates vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')  

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('Flagellates vs Chlorophyll by Region')
ax[1].set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of model flagellates vs observed Chlorophyll

# %%
fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Flagellates vs Chlorophyll')
ax.set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ### Model flagellates vs observed Chlorophyll comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (16,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ## All Model Phytoplankton vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets.

# %%
obsvar='Chl'
modvar='mod_Chl'

statsDict_Chl['All']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl['All'][isub]=dict()
    var=statsDict_Chl['All'][isub]
    var['N'],var['mmean'],omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=displayStats(statsDict_Chl['All'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=5></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >mmean</th>        <th class="col_heading level1 col1" >Bias</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>        <th class="col_heading level1 col4" >N</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row0_col0" class="data row0 col0" >2.076</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row0_col1" class="data row0 col1" >-2.988</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row0_col2" class="data row0 col2" >8.242</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row0_col3" class="data row0 col3" >0.368</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row0_col4" class="data row0 col4" >80209</td>
#             </tr>
#             <tr>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row1_col0" class="data row1 col0" >1.010</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row1_col1" class="data row1 col1" >-1.318</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row1_col2" class="data row1 col2" >3.002</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row1_col3" class="data row1 col3" >0.440</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row1_col4" class="data row1 col4" >36270</td>
#             </tr>
#             <tr>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row2_col0" class="data row2 col0" >0.382</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row2_col1" class="data row2 col1" >-0.735</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row2_col2" class="data row2 col2" >2.387</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row2_col3" class="data row2 col3" >0.215</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row2_col4" class="data row2 col4" >410861</td>
#             </tr>
#             <tr>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row3_col0" class="data row3 col0" >0.306</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row3_col1" class="data row3 col1" >-0.692</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row3_col2" class="data row3 col2" >2.584</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row3_col3" class="data row3 col3" >0.146</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row3_col4" class="data row3 col4" >286058</td>
#             </tr>
#             <tr>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row4_col0" class="data row4 col0" >0.683</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row4_col1" class="data row4 col1" >-1.118</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row4_col2" class="data row4 col2" >3.923</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row4_col3" class="data row4 col3" >0.382</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row4_col4" class="data row4 col4" >527340</td>
#             </tr>
#             <tr>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row5_col0" class="data row5 col0" >0.616</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row5_col1" class="data row5 col1" >-0.923</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row5_col2" class="data row5 col2" >2.651</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row5_col3" class="data row5 col3" >0.224</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row5_col4" class="data row5 col4" >15263</td>
#             </tr>
#             <tr>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row6_col0" class="data row6 col0" >2.524</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row6_col1" class="data row6 col1" >-3.636</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row6_col2" class="data row6 col2" >8.396</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row6_col3" class="data row6 col3" >0.429</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row6_col4" class="data row6 col4" >19372</td>
#             </tr>
#             <tr>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row7_col0" class="data row7 col0" >3.580</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row7_col1" class="data row7 col1" >-3.407</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row7_col2" class="data row7 col2" >10.307</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row7_col3" class="data row7 col3" >0.289</td>
#                         <td id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4row7_col4" class="data row7 col4" >20615</td>
#             </tr>
#             <tr>
#                         <th id="T_f9ce9ded_a796_11eb_a29e_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_Chl'

lims=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('Phytoplankton vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Model Phytoplankton (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]') 

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('Phytoplankton vs Chlorophyll by Depth')
ax[1].set_ylabel('log10[Model Phytoplankton (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of all model phytoplankton vs observed Chlorophyll

# %%
obsvar='log_Chl'
modvar='log_mod_Chl'

fig, ax = plt.subplots(1,1,figsize= (7,5))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('WADE CTD Data')
ax.set_ylabel('log10[Mod phytoplankton (mg/m$^3$)]',fontsize=16)
ax.set_xlabel('log10[Obs Chl (mg/m$^3$)]',fontsize=16)
# Out:
# Text(0.5, 19.0, 'log10[Obs Chl (mg/m$^3$)]')

# %% [markdown]
# ### 2D Histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ## Model Phytoplankton vs observed Chlorophyll comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (16,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,(-3.2,2),season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Model phytoplankton (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Chlorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### Summary table of evaluation statistics for Observed Chlorophyll Model Phytoplankton comparisons.

# %%
tbl,tdf=displayStats(statsDict_Chl,level='Variable',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=5></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >mmean</th>        <th class="col_heading level1 col1" >Bias</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>        <th class="col_heading level1 col4" >N</th>    </tr>    <tr>        <th class="index_name level0" >Variable</th>        <th class="index_name level1" ></th>        <th class="index_name level2" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level0_row0" class="row_heading level0 row0" rowspan=16>All</th>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level1_row0" class="row_heading level1 row0" >0</th>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level2_row0" class="row_heading level2 row0" >z < 15 m</th>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row0_col0" class="data row0 col0" >2.076</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row0_col1" class="data row0 col1" >-2.988</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row0_col2" class="data row0 col2" >8.242</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row0_col3" class="data row0 col3" >0.368</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row0_col4" class="data row0 col4" >80209</td>
#             </tr>
#             <tr>
#                                 <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level1_row1" class="row_heading level1 row1" >1</th>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level2_row1" class="row_heading level2 row1" >15 m < z < 22 m</th>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row1_col0" class="data row1 col0" >1.010</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row1_col1" class="data row1 col1" >-1.318</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row1_col2" class="data row1 col2" >3.002</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row1_col3" class="data row1 col3" >0.440</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row1_col4" class="data row1 col4" >36270</td>
#             </tr>
#             <tr>
#                                 <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level1_row2" class="row_heading level1 row2" >2</th>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level2_row2" class="row_heading level2 row2" >z >= 22 m</th>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row2_col0" class="data row2 col0" >0.382</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row2_col1" class="data row2 col1" >-0.735</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row2_col2" class="data row2 col2" >2.387</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row2_col3" class="data row2 col3" >0.215</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row2_col4" class="data row2 col4" >410861</td>
#             </tr>
#             <tr>
#                                 <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level1_row3" class="row_heading level1 row3" >3</th>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level2_row3" class="row_heading level2 row3" >z > 50 m</th>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row3_col0" class="data row3 col0" >0.306</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row3_col1" class="data row3 col1" >-0.692</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row3_col2" class="data row3 col2" >2.584</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row3_col3" class="data row3 col3" >0.146</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row3_col4" class="data row3 col4" >286058</td>
#             </tr>
#             <tr>
#                                 <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level1_row4" class="row_heading level1 row4" >4</th>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level2_row4" class="row_heading level2 row4" >all</th>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row4_col0" class="data row4 col0" >0.683</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row4_col1" class="data row4 col1" >-1.118</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row4_col2" class="data row4 col2" >3.923</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row4_col3" class="data row4 col3" >0.382</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row4_col4" class="data row4 col4" >527340</td>
#             </tr>
#             <tr>
#                                 <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level1_row5" class="row_heading level1 row5" >5</th>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level2_row5" class="row_heading level2 row5" >z < 15 m, DJF</th>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row5_col0" class="data row5 col0" >0.616</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row5_col1" class="data row5 col1" >-0.923</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row5_col2" class="data row5 col2" >2.651</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row5_col3" class="data row5 col3" >0.224</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row5_col4" class="data row5 col4" >15263</td>
#             </tr>
#             <tr>
#                                 <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level1_row6" class="row_heading level1 row6" >6</th>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level2_row6" class="row_heading level2 row6" >z < 15 m, MAM</th>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row6_col0" class="data row6 col0" >2.524</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row6_col1" class="data row6 col1" >-3.636</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row6_col2" class="data row6 col2" >8.396</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row6_col3" class="data row6 col3" >0.429</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row6_col4" class="data row6 col4" >19372</td>
#             </tr>
#             <tr>
#                                 <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level1_row7" class="row_heading level1 row7" >7</th>
#                         <th id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4level2_row7" class="row_heading level2 row7" >z < 15 m, JJA</th>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row7_col0" class="data row7 col0" >3.580</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row7_col1" class="data row7 col1" >-3.407</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row7_col2" class="data row7 col2" >10.307</td>
#                         <td id="T_fe41eb94_a796_11eb_bd51_10c37b4d98e4row7_col3" cl
