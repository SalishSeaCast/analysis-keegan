# %% [markdown]
# A notebook which contains an evaluation of the SalishSeaCast model within PugetSound. More specifically, it compares Observed data on temperature, salinity, and chlorophyll concentrations  collected from CTD data and compares it to various model phytoplankon outputs. This evaluation includes scatter plots and 2d histograms visualizing the similarity of observed and model data as well as tables of evaluation statistics.

# %%
import sys
sys.path.append('/ocean/kflanaga/MEOPAR/analysis-keegan/notebooks/Tools')

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import netCDF4 as nc
import datetime as dt
from salishsea_tools import evaltools as et, viz_tools
import gsw 
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import matplotlib.dates as mdates
import cmocean as cmo
import scipy.interpolate as sinterp
import pickle
import cmocean
import json
import f90nml
import Keegan_eval_tools as ket
from collections import OrderedDict
from matplotlib.colors import LogNorm

fs=16
mpl.rc('xtick', labelsize=fs)
mpl.rc('ytick', labelsize=fs)
mpl.rc('legend', fontsize=fs)
mpl.rc('axes', titlesize=fs)
mpl.rc('axes', labelsize=fs)
mpl.rc('figure', titlesize=fs)
mpl.rc('font', size=fs)
mpl.rc('font', family='sans-serif', weight='normal', style='normal')

import warnings
#warnings.filterwarnings('ignore')
from IPython.display import Markdown, display

# %matplotlib inline

# %% [raw]
# from IPython.display import HTML
#
# HTML('''<script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
years=range(2007,2020)
modelversion='nowcast-green.201905'
PATH= '/results2/SalishSea/nowcast-green.201905/'
datadir='/ocean/eolson/MEOPAR/obs/WADE/ptools_data/ecology'

# %%
display(Markdown('''## All years summary'''))
# Out:
# ## All years summary

# %%
display(Markdown('''### Model output: '''+ PATH))
# Out:
# ### Model output: /results2/SalishSea/nowcast-green.201905/

# %% [markdown]
# ## Yearly model-data comparisons of chlorophyll, temperature and salinity between 201905 runs and CTD observations

# %%
##### Loading in pickle file data
dictbot=dict()
saveloc='/ocean/kflanaga/MEOPAR/savedData'

for Y in years:
    with open(os.path.join(saveloc,f'data_CTD_{modelversion}_{Y}.pkl'),'rb') as hh:
        dictbot[Y]=pickle.load(hh)
    
data_CTD=pd.concat(dictbot.values(), ignore_index=True)

# %%
#Adding extra columns to assist in analysis.

Chl_to_N=1.8
data_CTD['log_Chl']=ket.logt(data_CTD['Chl'])
data_CTD['log_mod_diatoms']=ket.logt(data_CTD['mod_diatoms']*Chl_to_N)
data_CTD['log_mod_ciliates']=ket.logt(data_CTD['mod_ciliates']*Chl_to_N)
data_CTD['log_mod_flagellates']=ket.logt(data_CTD['mod_flagellates']*Chl_to_N)
data_CTD['mod_Chl']=((data_CTD['mod_diatoms']*Chl_to_N)+(data_CTD['mod_ciliates']*Chl_to_N)+(data_CTD['mod_flagellates']*Chl_to_N))
data_CTD['log_mod_Chl']=ket.logt((data_CTD['mod_diatoms']*Chl_to_N)+(data_CTD['mod_ciliates']*Chl_to_N)+(data_CTD['mod_flagellates']*Chl_to_N))

# defning a dictionary that brakes the data down by individual stations
datstat_CTD=dict()
for ind, istation in enumerate(data_CTD.Station.unique()):
    datstat_CTD[istation]=data_CTD.loc[data_CTD.Station == istation]

datreg_CTD=dict()
for iregion in data_CTD.Basin.unique():
    datreg_CTD[iregion] = data_CTD.loc[data_CTD.Basin==iregion]
# Out:
# /home/kflanaga/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Creating seperate dataframes for each season (includes only data above 15 metre depth.)
iz=(data_CTD.Z<15)
DJFd=dict()
MAMd=dict()
JJAd=dict()
SONd=dict()
for i in range(2008,2020):
    DJFd[i]=data_CTD.loc[iz&(data_CTD.dtUTC>=dt.datetime(i-1,12,1))&(data_CTD.dtUTC<=dt.datetime(i,3,1)),:]
    MAMd[i]=data_CTD.loc[iz&(data_CTD.dtUTC<=dt.datetime(i,6,1))&(data_CTD.dtUTC>dt.datetime(i,3,1)),:]
    JJAd[i]=data_CTD.loc[iz&(data_CTD.dtUTC<=dt.datetime(i,9,1))&(data_CTD.dtUTC>dt.datetime(i,6,1)),:]
    SONd[i]=data_CTD.loc[iz&(data_CTD.dtUTC>dt.datetime(i,9,1))&(data_CTD.dtUTC<=dt.datetime(i,11,30)),:]
DJF_CTD=pd.concat(DJFd.values(), ignore_index=True)
MAM_CTD=pd.concat(MAMd.values(), ignore_index=True)
JJA_CTD=pd.concat(JJAd.values(), ignore_index=True)
SON_CTD=pd.concat(SONd.values(), ignore_index=True)

# %%
### These groupings will be used to calculate statistics. The keys are labels and
### the values are corresponding dataframe views
statsubs_CTD=OrderedDict({'z < 15 m':data_CTD.loc[data_CTD.Z<15],
                      '15 m < z < 22 m':data_CTD.loc[(data_CTD.Z>=15)&(data_CTD.Z<22)],
                      'z >= 22 m':data_CTD.loc[data_CTD.Z>=22],
                      'z > 50 m':data_CTD.loc[data_CTD.Z>50],
                      'all':data_CTD,
                      'z < 15 m, DJF':DJF_CTD,
                      'z < 15 m, MAM':MAM_CTD,
                      'z < 15 m, JJA':JJA_CTD,
                      'z < 15 m, SON': SON_CTD})
for iregion in data_CTD.Basin.unique():
    statsubs_CTD[iregion]=datreg_CTD[iregion]
statsubs_CTD.keys()
# Out:
# odict_keys(['z < 15 m', '15 m < z < 22 m', 'z >= 22 m', 'z > 50 m', 'all', 'z < 15 m, DJF', 'z < 15 m, MAM', 'z < 15 m, JJA', 'z < 15 m, SON', 'Hood Canal Basin', 'Main Basin', 'Strait of Juan de Fuca', 'Strait of Georgia', 'Whidbey Basin', 'Admiralty Inlet', 'South Basin'])

# %% [markdown]
# ## Map of observation locations in each basin

# %%
fig, ax = plt.subplots(1,1,figsize = (6,6))
with nc.Dataset('/data/vdo/MEOPAR/NEMO-forcing/grid/bathymetry_201702.nc') as grid:
    viz_tools.plot_coastline(ax, grid, coords = 'map',isobath=.1)
colors=('blue','green','firebrick','darkorange','darkviolet','fuchsia',
        'royalblue','darkgoldenrod','mediumspringgreen','deepskyblue')
for ind, iregion in enumerate(data_CTD.Basin.unique()):
    ax.plot(datreg_CTD[iregion]['Lon'], datreg_CTD[iregion]['Lat'],'.',
            color = colors[ind], label=iregion)
ax.set_ylim(47, 49)
ax.legend(bbox_to_anchor=[1,.6,0,0])
ax.set_xlim(-124, -122);
ax.set_title('Observation Locations');

# %% [markdown]
# # Absolute Salinity (g/kg)

# %% [markdown]
# ### Table containing evaluation statistics for relevant subsets

# %%
# Setting Variable for Temperature. 
obsvar='SA'
modvar='mod_vosaline'
regions=data_CTD.Basin.unique()

# %%
statsDict_CTSA=dict()
statsDict_CTSA['SA']=OrderedDict()
for isub in statsubs_CTD:
    print(isub)
    statsDict_CTSA['SA'][isub]=dict()
    var=statsDict_CTSA['SA'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]],
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_CTSA['SA'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# z < 15 m
# 15 m < z < 22 m
# z >= 22 m
# z > 50 m
# all
# z < 15 m, DJF
# z < 15 m, MAM
# z < 15 m, JJA
# z < 15 m, SON
# Hood Canal Basin
# Main Basin
# Strait of Juan de Fuca
# Strait of Georgia
# Whidbey Basin
# Admiralty Inlet
# South Basin
# <style  type="text/css" >
# </style><table id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row0_col0" class="data row0 col0" >-0.464617</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row0_col1" class="data row0 col1" >96087.000000</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row0_col2" class="data row0 col2" >1.389067</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row0_col3" class="data row0 col3" >0.866613</td>
#             </tr>
#             <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row1_col0" class="data row1 col0" >-0.332660</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row1_col1" class="data row1 col1" >43202.000000</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row1_col2" class="data row1 col2" >0.648019</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row1_col3" class="data row1 col3" >0.878164</td>
#             </tr>
#             <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row2_col0" class="data row2 col0" >-0.092976</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row2_col1" class="data row2 col1" >495313.000000</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row2_col2" class="data row2 col2" >0.491051</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row2_col3" class="data row2 col3" >0.946643</td>
#             </tr>
#             <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row3_col0" class="data row3 col0" >-0.042067</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row3_col1" class="data row3 col1" >345419.000000</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row3_col2" class="data row3 col2" >0.474406</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row3_col3" class="data row3 col3" >0.952046</td>
#             </tr>
#             <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row4_col0" class="data row4 col0" >-0.165564</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row4_col1" class="data row4 col1" >634602.000000</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row4_col2" class="data row4 col2" >0.713404</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row4_col3" class="data row4 col3" >0.929387</td>
#             </tr>
#             <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row5_col0" class="data row5 col0" >-0.135284</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row5_col1" class="data row5 col1" >18415.000000</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row5_col2" class="data row5 col2" >1.478710</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row5_col3" class="data row5 col3" >0.863980</td>
#             </tr>
#             <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row6_col0" class="data row6 col0" >-0.313132</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row6_col1" class="data row6 col1" >23867.000000</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row6_col2" class="data row6 col2" >1.292841</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row6_col3" class="data row6 col3" >0.883618</td>
#             </tr>
#             <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row7_col0" class="data row7 col0" >-0.795120</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row7_col1" class="data row7 col1" >24183.000000</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row7_col2" class="data row7 col2" >1.489178</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row7_col3" class="data row7 col3" >0.845091</td>
#             </tr>
#             <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row8_col0" class="data row8 col0" >-0.554796</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row8_col1" class="data row8 col1" >22541.000000</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row8_col2" class="data row8 col2" >1.199333</td>
#                         <td id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4row8_col3" class="data row8 col3" >0.846097</td>
#             </tr>
#             <tr>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_fcc0efb5_7b88_11eb_821b_10c37b4d98e4level1_row9" class="row_heading level1 row9"

# %% [markdown]
# ### Model vs Observed comparisons by depth and region

# %%
lims=(0,40)

fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('S$_A$ (g kg$^{-1}$) By Depth')

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('S$_A$ (g kg$^{-1}$) By Region');

# %% [markdown]
# ### A closer look at Salinity in South Basin

# %% [markdown]
# ### 2D Histogram of model vs observed

# %%
fig, ax = plt.subplots(1,1,figsize= (12,8))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,lims,fontsize=18)
ax.set_title('S$_A$ (g kg$^{-1}$)',fontsize=18)
# Out:
# Text(0.5, 1.0, 'S$_A$ (g kg$^{-1}$)')

# %% [markdown]
# ### 2d histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ### Model vs observed comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (18,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('Modeled Salinity (g/kg)')
        ax[i][j].set_xlabel('Observed Salinity (g/kg)')

# %% [markdown]
# # Conservative Temperature

# %%
#Setting variables for temperature.
obsvar='CT'
modvar='mod_votemper'

# %% [markdown]
# ### Table containing evaluation statistics for relevant subsets

# %%
statsDict_CTSA['CT']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_CTSA['CT'][isub]=dict()
    var=statsDict_CTSA['CT'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]],
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_CTSA['CT'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row0_col0" class="data row0 col0" >0.091363</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row0_col1" class="data row0 col1" >96086.000000</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row0_col2" class="data row0 col2" >0.950648</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row0_col3" class="data row0 col3" >0.961215</td>
#             </tr>
#             <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row1_col0" class="data row1 col0" >-0.044225</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row1_col1" class="data row1 col1" >43202.000000</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row1_col2" class="data row1 col2" >0.536163</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row1_col3" class="data row1 col3" >0.975610</td>
#             </tr>
#             <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row2_col0" class="data row2 col0" >-0.148437</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row2_col1" class="data row2 col1" >495313.000000</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row2_col2" class="data row2 col2" >0.508570</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row2_col3" class="data row2 col3" >0.972278</td>
#             </tr>
#             <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row3_col0" class="data row3 col0" >-0.164723</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row3_col1" class="data row3 col1" >345419.000000</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row3_col2" class="data row3 col2" >0.500982</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row3_col3" class="data row3 col3" >0.971459</td>
#             </tr>
#             <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row4_col0" class="data row4 col0" >-0.105034</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row4_col1" class="data row4 col1" >634601.000000</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row4_col2" class="data row4 col2" >0.598565</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row4_col3" class="data row4 col3" >0.970660</td>
#             </tr>
#             <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row5_col0" class="data row5 col0" >-0.310225</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row5_col1" class="data row5 col1" >18415.000000</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row5_col2" class="data row5 col2" >0.697186</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row5_col3" class="data row5 col3" >0.895428</td>
#             </tr>
#             <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row6_col0" class="data row6 col0" >0.072707</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row6_col1" class="data row6 col1" >23867.000000</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row6_col2" class="data row6 col2" >0.606921</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row6_col3" class="data row6 col3" >0.953856</td>
#             </tr>
#             <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row7_col0" class="data row7 col0" >0.483676</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row7_col1" class="data row7 col1" >24182.000000</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row7_col2" class="data row7 col2" >1.445725</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row7_col3" class="data row7 col3" >0.892185</td>
#             </tr>
#             <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row8_col0" class="data row8 col0" >0.028354</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row8_col1" class="data row8 col1" >22541.000000</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row8_col2" class="data row8 col2" >0.699554</td>
#                         <td id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4row8_col3" class="data row8 col3" >0.961636</td>
#             </tr>
#             <tr>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_0192e8b6_7b89_11eb_bee1_10c37b4d98e4level1_row9" class="row_heading level1 row9" >Ho

# %% [markdown]
# ### Model vs Observed comparisons by depth and region

# %%
lims=(0,40)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('$\Theta$ ($^{\circ}$C) By Depth')

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('$\Theta$ ($^{\circ}$C) By Region');

# %% [markdown]
# ### 2D Histogram of model vs observed

# %%
fig, ax = plt.subplots(1,1,figsize= (12,8))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,lims,fontsize=18)
ax.set_title('$\Theta$ ($^{\circ}$C)',fontsize=18)
# Out:
# Text(0.5, 1.0, '$\\Theta$ ($^{\\circ}$C)')

# %% [markdown]
# ### 2d histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ### Model vs observed comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (18,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('Modeled Temperature (C$^o$)')
        ax[i][j].set_xlabel('Observed Salinity (C$^o$)')

# %% [markdown]
# ### Summary table of temperature and salinity evaluation statistics

# %%
tbl,tdf=et.displayStats(statsDict_CTSA,level='Variable',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" >Variable</th>        <th class="index_name level1" ></th>        <th class="index_name level2" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level0_row0" class="row_heading level0 row0" rowspan=16>CT</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level1_row0" class="row_heading level1 row0" >0</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level2_row0" class="row_heading level2 row0" >z < 15 m</th>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row0_col0" class="data row0 col0" >0.091363</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row0_col1" class="data row0 col1" >96086.000000</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row0_col2" class="data row0 col2" >0.950648</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row0_col3" class="data row0 col3" >0.961215</td>
#             </tr>
#             <tr>
#                                 <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level1_row1" class="row_heading level1 row1" >1</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level2_row1" class="row_heading level2 row1" >15 m < z < 22 m</th>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row1_col0" class="data row1 col0" >-0.044225</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row1_col1" class="data row1 col1" >43202.000000</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row1_col2" class="data row1 col2" >0.536163</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row1_col3" class="data row1 col3" >0.975610</td>
#             </tr>
#             <tr>
#                                 <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level1_row2" class="row_heading level1 row2" >2</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level2_row2" class="row_heading level2 row2" >z >= 22 m</th>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row2_col0" class="data row2 col0" >-0.148437</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row2_col1" class="data row2 col1" >495313.000000</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row2_col2" class="data row2 col2" >0.508570</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row2_col3" class="data row2 col3" >0.972278</td>
#             </tr>
#             <tr>
#                                 <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level1_row3" class="row_heading level1 row3" >3</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level2_row3" class="row_heading level2 row3" >z > 50 m</th>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row3_col0" class="data row3 col0" >-0.164723</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row3_col1" class="data row3 col1" >345419.000000</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row3_col2" class="data row3 col2" >0.500982</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row3_col3" class="data row3 col3" >0.971459</td>
#             </tr>
#             <tr>
#                                 <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level1_row4" class="row_heading level1 row4" >4</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level2_row4" class="row_heading level2 row4" >all</th>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row4_col0" class="data row4 col0" >-0.105034</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row4_col1" class="data row4 col1" >634601.000000</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row4_col2" class="data row4 col2" >0.598565</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row4_col3" class="data row4 col3" >0.970660</td>
#             </tr>
#             <tr>
#                                 <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level1_row5" class="row_heading level1 row5" >5</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level2_row5" class="row_heading level2 row5" >z < 15 m, DJF</th>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row5_col0" class="data row5 col0" >-0.310225</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row5_col1" class="data row5 col1" >18415.000000</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row5_col2" class="data row5 col2" >0.697186</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row5_col3" class="data row5 col3" >0.895428</td>
#             </tr>
#             <tr>
#                                 <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level1_row6" class="row_heading level1 row6" >6</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level2_row6" class="row_heading level2 row6" >z < 15 m, MAM</th>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row6_col0" class="data row6 col0" >0.072707</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row6_col1" class="data row6 col1" >23867.000000</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row6_col2" class="data row6 col2" >0.606921</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row6_col3" class="data row6 col3" >0.953856</td>
#             </tr>
#             <tr>
#                                 <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level1_row7" class="row_heading level1 row7" >7</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level2_row7" class="row_heading level2 row7" >z < 15 m, JJA</th>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row7_col0" class="data row7 col0" >0.483676</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row7_col1" class="data row7 col1" >24182.000000</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row7_col2" class="data row7 col2" >1.445725</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row7_col3" class="data row7 col3" >0.892185</td>
#             </tr>
#             <tr>
#                                 <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level1_row8" class="row_heading level1 row8" >8</th>
#                         <th id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4level2_row8" class="row_heading level2 row8" >z < 15 m, SON</th>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row8_col0" class="data row8 col0" >0.028354</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row8_col1" class="data row8 col1" >22541.000000</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row8_col2" class="data row8 col2" >0.699554</td>
#                         <td id="T_0639ec58_7b89_11eb_a8cc_10c37b4d98e4row8_col3"

# %% [markdown]
# # Observed Chlorophyll vs Model Phytoplankton

# %%
#Setting variables for Chlorophyll.
obsvar='Chl'
modvar='mod_diatoms'

# %% [markdown]
# ## Model Diatoms vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets

# %%
statsDict_Chl=dict()
statsDict_Chl['Diatoms']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl['Diatoms'][isub]=dict()
    var=statsDict_Chl['Diatoms'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_Chl['Diatoms'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row0_col0" class="data row0 col0" >-4.523909</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row0_col1" class="data row0 col1" >80209.000000</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row0_col2" class="data row0 col2" >9.205986</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row0_col3" class="data row0 col3" >0.338156</td>
#             </tr>
#             <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row1_col0" class="data row1 col0" >-2.092093</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row1_col1" class="data row1 col1" >36270.000000</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row1_col2" class="data row1 col2" >3.529910</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row1_col3" class="data row1 col3" >0.379680</td>
#             </tr>
#             <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row2_col0" class="data row2 col0" >-1.047373</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row2_col1" class="data row2 col1" >410861.000000</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row2_col2" class="data row2 col2" >2.531491</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row2_col3" class="data row2 col3" >0.212749</td>
#             </tr>
#             <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row3_col0" class="data row3 col0" >-0.945413</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row3_col1" class="data row3 col1" >286058.000000</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row3_col2" class="data row3 col2" >2.683813</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row3_col3" class="data row3 col3" >0.159158</td>
#             </tr>
#             <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row4_col0" class="data row4 col0" >-1.648013</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row4_col1" class="data row4 col1" >527340.000000</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row4_col2" class="data row4 col2" >4.329036</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row4_col3" class="data row4 col3" >0.249724</td>
#             </tr>
#             <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row5_col0" class="data row5 col0" >-1.529342</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row5_col1" class="data row5 col1" >15263.000000</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row5_col2" class="data row5 col2" >2.969877</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row5_col3" class="data row5 col3" >0.255288</td>
#             </tr>
#             <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row6_col0" class="data row6 col0" >-5.193634</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row6_col1" class="data row6 col1" >19372.000000</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row6_col2" class="data row6 col2" >9.363626</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row6_col3" class="data row6 col3" >0.404923</td>
#             </tr>
#             <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row7_col0" class="data row7 col0" >-6.141769</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row7_col1" class="data row7 col1" >20615.000000</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row7_col2" class="data row7 col2" >11.751375</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row7_col3" class="data row7 col3" >0.317760</td>
#             </tr>
#             <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row8_col0" class="data row8 col0" >-4.127788</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row8_col1" class="data row8 col1" >18640.000000</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row8_col2" class="data row8 col2" >8.511545</td>
#                         <td id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4row8_col3" class="data row8 col3" >0.300884</td>
#             </tr>
#             <tr>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_06464ea3_7b89_11eb_b56e_10c37b4d98e4level1_row9" class="row_heading level1 row9

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_diatoms'

lims=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('Diatoms vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')   

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('Diatoms vs Chlorophyll by Region');
ax[1].set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of model diatoms vs observed cholophyll

# %%
fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Diatoms vs Chlorophyl')
ax.set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2d histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ### Model vs observed comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (18,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ## Model Ciliates vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets.

# %%
obsvar='Chl'
modvar='mod_ciliates'

statsDict_Chl['Ciliates']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl['Ciliates'][isub]=dict()
    var=statsDict_Chl['Ciliates'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_Chl['Ciliates'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row0_col0" class="data row0 col0" >-4.893798</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row0_col1" class="data row0 col1" >80209.000000</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row0_col2" class="data row0 col2" >9.515966</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row0_col3" class="data row0 col3" >0.329075</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row1_col0" class="data row1 col0" >-2.213752</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row1_col1" class="data row1 col1" >36270.000000</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row1_col2" class="data row1 col2" >3.691019</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row1_col3" class="data row1 col3" >0.358916</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row2_col0" class="data row2 col0" >-1.050897</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row2_col1" class="data row2 col1" >410861.000000</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row2_col2" class="data row2 col2" >2.554234</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row2_col3" class="data row2 col3" >0.205420</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row3_col0" class="data row3 col0" >-0.938705</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row3_col1" class="data row3 col1" >286058.000000</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row3_col2" class="data row3 col2" >2.694288</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row3_col3" class="data row3 col3" >0.155180</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row4_col0" class="data row4 col0" >-1.715386</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row4_col1" class="data row4 col1" >527340.000000</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row4_col2" class="data row4 col2" >4.448976</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row4_col3" class="data row4 col3" >0.222506</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row5_col0" class="data row5 col0" >-1.423616</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row5_col1" class="data row5 col1" >15263.000000</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row5_col2" class="data row5 col2" >2.912262</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row5_col3" class="data row5 col3" >0.250291</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row6_col0" class="data row6 col0" >-5.992172</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row6_col1" class="data row6 col1" >19372.000000</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row6_col2" class="data row6 col2" >10.093204</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row6_col3" class="data row6 col3" >0.384818</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row7_col0" class="data row7 col0" >-6.753928</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row7_col1" class="data row7 col1" >20615.000000</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row7_col2" class="data row7 col2" >12.040835</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row7_col3" class="data row7 col3" >0.326672</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row8_col0" class="data row8 col0" >-4.156519</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row8_col1" class="data row8 col1" >18640.000000</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row8_col2" class="data row8 col2" >8.530294</td>
#                         <td id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4row8_col3" class="data row8 col3" >0.299290</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_0ae5c0f9_7b89_11eb_92b0_10c37b4d98e4level1_row9" class="row_heading level1 row

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_ciliates'

lims=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('Cliliates vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Model Ciliates (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')  

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('Cliliates vs Chlorophyll by Region')
ax[1].set_ylabel('log10[Model Ciliates (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of model ciliates vs observed chlorophyll

# %%
fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Cliliates vs Chlorophyll')
ax.set_ylabel('log10[Model Ciliates (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ## Model Ciliates vs observed Chlorophyll comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (16,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Modeled Cilliates (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ## Model Flagellates vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets.

# %%
obsvar='Chl'
modvar='mod_flagellates'

statsDict_Chl['Flagellates']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl['Flagellates'][isub]=dict()
    var=statsDict_Chl['Flagellates'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_Chl['Flagellates'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row0_col0" class="data row0 col0" >-4.619668</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row0_col1" class="data row0 col1" >80209.000000</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row0_col2" class="data row0 col2" >9.263906</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row0_col3" class="data row0 col3" >0.334513</td>
#             </tr>
#             <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row1_col0" class="data row1 col0" >-2.117056</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row1_col1" class="data row1 col1" >36270.000000</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row1_col2" class="data row1 col2" >3.600757</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row1_col3" class="data row1 col3" >0.364355</td>
#             </tr>
#             <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row2_col0" class="data row2 col0" >-1.042783</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row2_col1" class="data row2 col1" >410861.000000</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row2_col2" class="data row2 col2" >2.550727</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row2_col3" class="data row2 col3" >0.205606</td>
#             </tr>
#             <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row3_col0" class="data row3 col0" >-0.938540</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row3_col1" class="data row3 col1" >286058.000000</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row3_col2" class="data row3 col2" >2.695985</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row3_col3" class="data row3 col3" >0.155214</td>
#             </tr>
#             <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row4_col0" class="data row4 col0" >-1.660719</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row4_col1" class="data row4 col1" >527340.000000</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row4_col2" class="data row4 col2" >4.360525</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row4_col3" class="data row4 col3" >0.236686</td>
#             </tr>
#             <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row5_col0" class="data row5 col0" >-1.324365</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row5_col1" class="data row5 col1" >15263.000000</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row5_col2" class="data row5 col2" >2.855443</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row5_col3" class="data row5 col3" >0.246979</td>
#             </tr>
#             <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row6_col0" class="data row6 col0" >-5.890631</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row6_col1" class="data row6 col1" >19372.000000</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row6_col2" class="data row6 col2" >10.010886</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row6_col3" class="data row6 col3" >0.385297</td>
#             </tr>
#             <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row7_col0" class="data row7 col0" >-6.075518</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row7_col1" class="data row7 col1" >20615.000000</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row7_col2" class="data row7 col2" >11.518934</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row7_col3" class="data row7 col3" >0.329385</td>
#             </tr>
#             <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row8_col0" class="data row8 col0" >-3.991662</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row8_col1" class="data row8 col1" >18640.000000</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row8_col2" class="data row8 col2" >8.358845</td>
#                         <td id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4row8_col3" class="data row8 col3" >0.304951</td>
#             </tr>
#             <tr>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_0f3a823f_7b89_11eb_8034_10c37b4d98e4level1_row9" class="row_heading level1 row

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_flagellates'

lims=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('Flagellates vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')  

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('Flagellates vs Chlorophyll by Region')
ax[1].set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of model flagellates vs observed Chlorophyll

# %%
fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Flagellates vs Chlorophyll')
ax.set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ### Model flagellates vs observed Chlorophyll comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (16,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,lims,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ## All Model Phytoplankton vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets.

# %%
obsvar='Chl'
modvar='mod_Chl'

statsDict_Chl['All']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl['All'][isub]=dict()
    var=statsDict_Chl['All'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_Chl['All'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_137320cf_7b89_11eb_9428_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row0_col0" class="data row0 col0" >-2.987562</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row0_col1" class="data row0 col1" >80209.000000</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row0_col2" class="data row0 col2" >8.242463</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row0_col3" class="data row0 col3" >0.368002</td>
#             </tr>
#             <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row1_col0" class="data row1 col0" >-1.318108</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row1_col1" class="data row1 col1" >36270.000000</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row1_col2" class="data row1 col2" >3.002182</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row1_col3" class="data row1 col3" >0.440053</td>
#             </tr>
#             <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row2_col0" class="data row2 col0" >-0.735480</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row2_col1" class="data row2 col1" >410861.000000</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row2_col2" class="data row2 col2" >2.387066</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row2_col3" class="data row2 col3" >0.215380</td>
#             </tr>
#             <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row3_col0" class="data row3 col0" >-0.691884</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row3_col1" class="data row3 col1" >286058.000000</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row3_col2" class="data row3 col2" >2.584481</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row3_col3" class="data row3 col3" >0.146242</td>
#             </tr>
#             <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row4_col0" class="data row4 col0" >-1.118097</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row4_col1" class="data row4 col1" >527340.000000</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row4_col2" class="data row4 col2" >3.923376</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row4_col3" class="data row4 col3" >0.381912</td>
#             </tr>
#             <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row5_col0" class="data row5 col0" >-0.923479</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row5_col1" class="data row5 col1" >15263.000000</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row5_col2" class="data row5 col2" >2.651429</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row5_col3" class="data row5 col3" >0.223561</td>
#             </tr>
#             <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row6_col0" class="data row6 col0" >-3.635601</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row6_col1" class="data row6 col1" >19372.000000</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row6_col2" class="data row6 col2" >8.395644</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row6_col3" class="data row6 col3" >0.429212</td>
#             </tr>
#             <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row7_col0" class="data row7 col0" >-3.406938</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row7_col1" class="data row7 col1" >20615.000000</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row7_col2" class="data row7 col2" >10.306939</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row7_col3" class="data row7 col3" >0.288764</td>
#             </tr>
#             <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row8_col0" class="data row8 col0" >-3.203012</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row8_col1" class="data row8 col1" >18640.000000</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row8_col2" class="data row8 col2" >7.928773</td>
#                         <td id="T_137320cf_7b89_11eb_9428_10c37b4d98e4row8_col3" class="data row8 col3" >0.305842</td>
#             </tr>
#             <tr>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_137320cf_7b89_11eb_9428_10c37b4d98e4level1_row9" class="row_heading level1 row9

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_Chl'

lims=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,lims)
ax[0].set_title('Phytoplankton vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Model Phytoplankton (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]') 

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,lims)
ax[1].set_title('Phytoplankton vs Chlorophyll by Depth')
ax[1].set_ylabel('log10[Model Phytoplankton (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of all model phytoplankton vs observed Chlorophyll

# %%
obsvar='log_Chl'
modvar='log_mod_Chl'

fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Phytoplankton vs Chlorophyll')
ax.set_ylabel('log10[Model Phytoplankton (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Chlorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Chlorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histograms of individual regions

# %%
ax=ket.byRegion_hist2d(datreg_CTD,regions,obsvar,modvar,lims)

# %% [markdown]
# ## Model Phytoplankton vs observed Chlorophyll comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (16,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,(-3.2,2),season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Model phytoplankton (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Chlorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### Summary table of evaluation statistics for Observed Chlorophyll Model Phytoplankton comparisons.

# %%
tbl,tdf=et.displayStats(statsDict_Chl,level='Variable',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" >Variable</th>        <th class="index_name level1" ></th>        <th class="index_name level2" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level0_row0" class="row_heading level0 row0" rowspan=16>All</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level1_row0" class="row_heading level1 row0" >0</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level2_row0" class="row_heading level2 row0" >z < 15 m</th>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row0_col0" class="data row0 col0" >-2.987562</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row0_col1" class="data row0 col1" >80209.000000</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row0_col2" class="data row0 col2" >8.242463</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row0_col3" class="data row0 col3" >0.368002</td>
#             </tr>
#             <tr>
#                                 <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level1_row1" class="row_heading level1 row1" >1</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level2_row1" class="row_heading level2 row1" >15 m < z < 22 m</th>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row1_col0" class="data row1 col0" >-1.318108</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row1_col1" class="data row1 col1" >36270.000000</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row1_col2" class="data row1 col2" >3.002182</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row1_col3" class="data row1 col3" >0.440053</td>
#             </tr>
#             <tr>
#                                 <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level1_row2" class="row_heading level1 row2" >2</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level2_row2" class="row_heading level2 row2" >z >= 22 m</th>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row2_col0" class="data row2 col0" >-0.735480</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row2_col1" class="data row2 col1" >410861.000000</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row2_col2" class="data row2 col2" >2.387066</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row2_col3" class="data row2 col3" >0.215380</td>
#             </tr>
#             <tr>
#                                 <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level1_row3" class="row_heading level1 row3" >3</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level2_row3" class="row_heading level2 row3" >z > 50 m</th>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row3_col0" class="data row3 col0" >-0.691884</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row3_col1" class="data row3 col1" >286058.000000</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row3_col2" class="data row3 col2" >2.584481</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row3_col3" class="data row3 col3" >0.146242</td>
#             </tr>
#             <tr>
#                                 <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level1_row4" class="row_heading level1 row4" >4</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level2_row4" class="row_heading level2 row4" >all</th>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row4_col0" class="data row4 col0" >-1.118097</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row4_col1" class="data row4 col1" >527340.000000</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row4_col2" class="data row4 col2" >3.923376</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row4_col3" class="data row4 col3" >0.381912</td>
#             </tr>
#             <tr>
#                                 <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level1_row5" class="row_heading level1 row5" >5</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level2_row5" class="row_heading level2 row5" >z < 15 m, DJF</th>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row5_col0" class="data row5 col0" >-0.923479</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row5_col1" class="data row5 col1" >15263.000000</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row5_col2" class="data row5 col2" >2.651429</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row5_col3" class="data row5 col3" >0.223561</td>
#             </tr>
#             <tr>
#                                 <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level1_row6" class="row_heading level1 row6" >6</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level2_row6" class="row_heading level2 row6" >z < 15 m, MAM</th>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row6_col0" class="data row6 col0" >-3.635601</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row6_col1" class="data row6 col1" >19372.000000</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row6_col2" class="data row6 col2" >8.395644</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row6_col3" class="data row6 col3" >0.429212</td>
#             </tr>
#             <tr>
#                                 <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level1_row7" class="row_heading level1 row7" >7</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level2_row7" class="row_heading level2 row7" >z < 15 m, JJA</th>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row7_col0" class="data row7 col0" >-3.406938</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row7_col1" class="data row7 col1" >20615.000000</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row7_col2" class="data row7 col2" >10.306939</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row7_col3" class="data row7 col3" >0.288764</td>
#             </tr>
#             <tr>
#                                 <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level1_row8" class="row_heading level1 row8" >8</th>
#                         <th id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4level2_row8" class="row_heading level2 row8" >z < 15 m, SON</th>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row8_col0" class="data row8 col0" >-3.203012</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row8_col1" class="data row8 col1" >18640.000000</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row8_col2" class="data row8 col2" >7.928773</td>
#                         <td id="T_17e2b1a8_7b89_11eb_924b_10c37b4d98e4row8_
