# %% [markdown]
# A notebook which contains an evaluation of the SalishSeaCast model within PugetSound for the year 2009. More specifically, it compares Observed data on temperature, salinity, and chlorophyll concentrations  collected from CTD data and compares it to various model phytoplankon outputs. This evaluation includes scatter plots and 2d histograms visualizing the similarity of observed and model data as well as tables of evaluation statistics.

# %%
import sys
sys.path.append('/ocean/kflanaga/MEOPAR/analysis-keegan/notebooks/Tools')

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import netCDF4 as nc
import datetime as dt
from salishsea_tools import evaltools as et, viz_tools
import gsw 
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import matplotlib.dates as mdates
import cmocean as cmo
import scipy.interpolate as sinterp
import pickle
import cmocean
import json
import f90nml
import Keegan_eval_tools as ket
from collections import OrderedDict
from matplotlib.colors import LogNorm

fs=16
mpl.rc('xtick', labelsize=fs)
mpl.rc('ytick', labelsize=fs)
mpl.rc('legend', fontsize=fs)
mpl.rc('axes', titlesize=fs)
mpl.rc('axes', labelsize=fs)
mpl.rc('figure', titlesize=fs)
mpl.rc('font', size=fs)
mpl.rc('font', family='sans-serif', weight='normal', style='normal')

import warnings
#warnings.filterwarnings('ignore')
from IPython.display import Markdown, display

# %matplotlib inline

# %% [raw]
# from IPython.display import HTML
#
# HTML('''<script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
years=[2008,2009]
year=2009
modelversion='nowcast-green.201905'
PATH= '/results2/SalishSea/nowcast-green.201905/'
datadir='/ocean/eolson/MEOPAR/obs/WADE/ptools_data/ecology'

# %%
display(Markdown('''## Year: '''+ str(year)))
# Out:
# ## Year: 2009

# %%
display(Markdown('''### Model output: '''+ PATH))
# Out:
# ### Model output: /results2/SalishSea/nowcast-green.201905/

# %% [markdown]
# ## Yearly model-data comparisons of chlorophyll, temperature and salinity between 201905 runs and CTD observations

# %%
##### Loading in pickle file data
saveloc='/ocean/kflanaga/MEOPAR/savedData'
with open(os.path.join(saveloc,f'data_CTD_{modelversion}_{year}.pkl'),'rb') as hh:
    data_CTD=pickle.load(hh)

# %%
#Adding extra columns to assist in analysis.
data_CTD['log_Chl']=ket.logt(data_CTD['Chl'])
data_CTD['log_mod_diatoms']=ket.logt(data_CTD['mod_diatoms']*1.8)
data_CTD['log_mod_ciliates']=ket.logt(data_CTD['mod_ciliates']*1.8)
data_CTD['log_mod_flagellates']=ket.logt(data_CTD['mod_flagellates']*1.8)
data_CTD['mod_Chl']=((data_CTD['mod_diatoms']*1.8)+(data_CTD['mod_ciliates']*1.8)+(data_CTD['mod_flagellates']*1.8))
data_CTD['log_mod_Chl']=ket.logt((data_CTD['mod_diatoms']*1.8)+(data_CTD['mod_ciliates']*1.8)+(data_CTD['mod_flagellates']*1.8))

# defning a dictionary that brakes the data down by individual stations
datstat_CTD=dict()
for ind, istation in enumerate(data_CTD.Station.unique()):
    datstat_CTD[istation]=data_CTD.loc[data_CTD.Station == istation]

datreg_CTD=dict()
for iregion in data_CTD.Basin.unique():
    datreg_CTD[iregion] = data_CTD.loc[data_CTD.Basin==iregion]

# %%
# Creating seperate dataframes for each season (includes only dataabove 15 metre depth.)
iz=(data_CTD.Z<15)
DJF_CTD=data_CTD.loc[iz&(data_CTD.dtUTC>=dt.datetime(years[0],12,1))&(data_CTD.dtUTC<=dt.datetime(years[1],3,1)),:]
MAM_CTD=data_CTD.loc[iz&(data_CTD.dtUTC<=dt.datetime(years[1],5,1))&(data_CTD.dtUTC>dt.datetime(years[1],4,1)),:]
JJA_CTD=data_CTD.loc[iz&(data_CTD.dtUTC<=dt.datetime(years[1],9,1))&(data_CTD.dtUTC>dt.datetime(years[1],5,1)),:]
SON_CTD=data_CTD.loc[iz&(data_CTD.dtUTC>dt.datetime(years[1],9,1))&(data_CTD.dtUTC<=dt.datetime(years[1],12,31)),:]

# %%
### These groupings will be used to calculate statistics. The keys are labels and
### the values are corresponding dataframe views
statsubs_CTD=OrderedDict({'z < 15 m':data_CTD.loc[data_CTD.Z<15],
                      '15 m < z < 22 m':data_CTD.loc[(data_CTD.Z>=15)&(data_CTD.Z<22)],
                      'z >= 22 m':data_CTD.loc[data_CTD.Z>=22],
                      'z > 50 m':data_CTD.loc[data_CTD.Z>50],
                      'all':data_CTD,
                      'z < 15 m, DJF':DJF_CTD,
                      'z < 15 m, MAM':MAM_CTD,
                      'z < 15 m, JJA':JJA_CTD,
                      'z < 15 m, SON': SON_CTD})
for iregion in data_CTD.Basin.unique():
    statsubs_CTD[iregion]=datreg_CTD[iregion]
statsubs_CTD.keys()
# Out:
# odict_keys(['z < 15 m', '15 m < z < 22 m', 'z >= 22 m', 'z > 50 m', 'all', 'z < 15 m, DJF', 'z < 15 m, MAM', 'z < 15 m, JJA', 'z < 15 m, SON', 'Strait of Juan de Fuca', 'Main Basin', 'Hood Canal Basin', 'Strait of Georgia', 'Admiralty Inlet', 'Whidbey Basin', 'South Basin'])

# %% [markdown]
# ## Map of observation locations in each basin

# %%
fig, ax = plt.subplots(1,1,figsize = (6,6))
with nc.Dataset('/data/vdo/MEOPAR/NEMO-forcing/grid/bathymetry_201702.nc') as grid:
    viz_tools.plot_coastline(ax, grid, coords = 'map',isobath=.1)
colors=('blue','green','firebrick','darkorange','darkviolet','fuchsia',
        'royalblue','darkgoldenrod','mediumspringgreen','deepskyblue')
for ind, iregion in enumerate(data_CTD.Basin.unique()):
    ax.plot(datreg_CTD[iregion]['Lon'], datreg_CTD[iregion]['Lat'],'.',
            color = colors[ind], label=iregion)
ax.set_ylim(47, 49)
ax.legend(bbox_to_anchor=[1,.6,0,0])
ax.set_xlim(-124, -122);
ax.set_title('Observation Locations');

# %% [markdown]
# # Absolute Salinity (g/kg)

# %% [markdown]
# ### Table containing evaluation statistics for relevant subsets

# %%
# Setting Variable for Temperature. 
obsvar='SA'
modvar='mod_vosaline'

# %%
statsDict_CTSA={year:dict()}
statsDict_CTSA[year]['SA']=OrderedDict()
for isub in statsubs_CTD:
    print(isub)
    statsDict_CTSA[year]['SA'][isub]=dict()
    var=statsDict_CTSA[year]['SA'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]],
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_CTSA[year]['SA'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# z < 15 m
# 15 m < z < 22 m
# z >= 22 m
# z > 50 m
# all
# z < 15 m, DJF
# z < 15 m, MAM
# z < 15 m, JJA
# z < 15 m, SON
# Strait of Juan de Fuca
# Main Basin
# Hood Canal Basin
# Strait of Georgia
# Admiralty Inlet
# Whidbey Basin
# South Basin
# <style  type="text/css" >
# </style><table id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row0_col0" class="data row0 col0" >-0.683895</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row0_col1" class="data row0 col1" >6619.000000</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row0_col2" class="data row0 col2" >1.328930</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row0_col3" class="data row0 col3" >0.859306</td>
#             </tr>
#             <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row1_col0" class="data row1 col0" >-0.443340</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row1_col1" class="data row1 col1" >2990.000000</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row1_col2" class="data row1 col2" >0.676286</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row1_col3" class="data row1 col3" >0.837533</td>
#             </tr>
#             <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row2_col0" class="data row2 col0" >-0.086844</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row2_col1" class="data row2 col1" >33877.000000</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row2_col2" class="data row2 col2" >0.437982</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row2_col3" class="data row2 col3" >0.945295</td>
#             </tr>
#             <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row3_col0" class="data row3 col0" >-0.007053</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row3_col1" class="data row3 col1" >23355.000000</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row3_col2" class="data row3 col2" >0.414447</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row3_col3" class="data row3 col3" >0.953427</td>
#             </tr>
#             <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row4_col0" class="data row4 col0" >-0.202233</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row4_col1" class="data row4 col1" >43486.000000</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row4_col2" class="data row4 col2" >0.670596</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row4_col3" class="data row4 col3" >0.922815</td>
#             </tr>
#             <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row5_col0" class="data row5 col0" >-0.400450</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row5_col1" class="data row5 col1" >165.000000</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row5_col2" class="data row5 col2" >0.540323</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row5_col3" class="data row5 col3" >0.344325</td>
#             </tr>
#             <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row6_col0" class="data row6 col0" >-0.761217</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row6_col1" class="data row6 col1" >622.000000</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row6_col2" class="data row6 col2" >1.417353</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row6_col3" class="data row6 col3" >0.854687</td>
#             </tr>
#             <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row7_col0" class="data row7 col0" >-0.807223</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row7_col1" class="data row7 col1" >2873.000000</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row7_col2" class="data row7 col2" >1.386531</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row7_col3" class="data row7 col3" >0.867965</td>
#             </tr>
#             <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row8_col0" class="data row8 col0" >-0.468337</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row8_col1" class="data row8 col1" >2417.000000</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row8_col2" class="data row8 col2" >1.252503</td>
#                         <td id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4row8_col3" class="data row8 col3" >0.835299</td>
#             </tr>
#             <tr>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_29832532_6bcd_11eb_8c08_10c37b4d98e4level1_row9" class="row_heading level1 row9" >Strait of

# %% [markdown]
# ### Model vs Observed comparisons by depth and region

# %%
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,(0,40))
ax[0].set_title('S$_A$ (g kg$^{-1}$) By Depth')

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,(0,40))
ax[1].set_title('S$_A$ (g kg$^{-1}$) By Region');

# %% [markdown]
# ### A closer look at Salinity in South Basin

# %%
# Look at the salinity and divide up by depth. 
basin=data_CTD.Basin.unique()[6]
lims=(0,40)
ps=[]
fig, ax=plt.subplots(1,1,figsize=(12,8))
ax.plot(datreg_CTD[basin]['Lon'], datreg_CTD[basin]['Lat'],'.',
            color = colors[ind], label=basin)
ps0=et.varvarPlot(ax,datreg_CTD[basin],obsvar,modvar,
             cols=(colors[0],),lname=basin)
ps.append(ps0)
l=ax.legend(title='Stations',title_fontsize=20,handles=[ip[0][0] for ip in ps])
ax.set_xlabel('Obs')
ax.set_ylabel('Model')
ax.plot(lims,lims,'k-',alpha=.5)
ax.set_xlim(lims)
ax.set_ylim(lims)
ax.set_aspect(1)

# %% [markdown]
# ### 2D Histogram of model vs observed

# %%
fig, ax = plt.subplots(1,1,figsize= (12,8))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(0,40),fontsize=18)
ax.set_title('S$_A$ (g kg$^{-1}$)',fontsize=18)
# Out:
# Text(0.5, 1.0, 'S$_A$ (g kg$^{-1}$)')

# %% [markdown]
# ### Model vs observed comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(1,4,figsize = (16,3.3))
ket.bySeason(ax,seasons,obsvar,modvar,(0,40),season_titles)
fig,ax=plt.subplots(1,1,figsize=(20,.3))
ax.plot(data_CTD.dtUTC,np.ones(np.shape(data_CTD.dtUTC)),'k.')
ax.set_xlim((dt.datetime(year,1,1),dt.datetime(year,12,31)))
ax.set_title('data_CTD Timing')
ax.yaxis.set_visible(False)

# %% [markdown]
# # Conservative Temperature

# %%
#Setting variables for temperature.
obsvar='CT'
modvar='mod_votemper'

# %% [markdown]
# ### Table containing evaluation statistics for relevant subsets

# %%
statsDict_CTSA[year]['CT']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_CTSA[year]['CT'][isub]=dict()
    var=statsDict_CTSA[year]['CT'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]],
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_CTSA[year]['CT'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row0_col0" class="data row0 col0" >0.144905</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row0_col1" class="data row0 col1" >6619.000000</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row0_col2" class="data row0 col2" >1.091836</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row0_col3" class="data row0 col3" >0.950838</td>
#             </tr>
#             <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row1_col0" class="data row1 col0" >-0.149377</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row1_col1" class="data row1 col1" >2990.000000</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row1_col2" class="data row1 col2" >0.714967</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row1_col3" class="data row1 col3" >0.960686</td>
#             </tr>
#             <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row2_col0" class="data row2 col0" >-0.207084</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row2_col1" class="data row2 col1" >33877.000000</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row2_col2" class="data row2 col2" >0.573705</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row2_col3" class="data row2 col3" >0.968953</td>
#             </tr>
#             <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row3_col0" class="data row3 col0" >-0.208076</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row3_col1" class="data row3 col1" >23355.000000</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row3_col2" class="data row3 col2" >0.531465</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row3_col3" class="data row3 col3" >0.971649</td>
#             </tr>
#             <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row4_col0" class="data row4 col0" >-0.149540</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row4_col1" class="data row4 col1" >43486.000000</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row4_col2" class="data row4 col2" >0.687755</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row4_col3" class="data row4 col3" >0.965929</td>
#             </tr>
#             <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row5_col0" class="data row5 col0" >-0.212395</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row5_col1" class="data row5 col1" >165.000000</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row5_col2" class="data row5 col2" >0.238863</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row5_col3" class="data row5 col3" >0.529533</td>
#             </tr>
#             <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row6_col0" class="data row6 col0" >0.213620</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row6_col1" class="data row6 col1" >622.000000</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row6_col2" class="data row6 col2" >0.457542</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row6_col3" class="data row6 col3" >0.862394</td>
#             </tr>
#             <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row7_col0" class="data row7 col0" >0.464440</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row7_col1" class="data row7 col1" >2873.000000</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row7_col2" class="data row7 col2" >1.481652</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row7_col3" class="data row7 col3" >0.888637</td>
#             </tr>
#             <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row8_col0" class="data row8 col0" >-0.212655</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row8_col1" class="data row8 col1" >2417.000000</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row8_col2" class="data row8 col2" >0.732654</td>
#                         <td id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4row8_col3" class="data row8 col3" >0.961526</td>
#             </tr>
#             <tr>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_2a88aaf5_6bcd_11eb_99f1_10c37b4d98e4level1_row9" class="row_heading level1 row9" >Strait of Ju

# %% [markdown]
# ### Model vs Observed comparisons by depth and region

# %%
mv=(0,40)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,mv)
ax[0].set_title('$\Theta$ ($^{\circ}$C) By Depth')

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,mv)
ax[1].set_title('$\Theta$ ($^{\circ}$C) By Region');

# %% [markdown]
# ### 2D Histogram of model vs observed

# %%
fig, ax = plt.subplots(1,1,figsize= (12,8))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(0,40),fontsize=18)
ax.set_title('$\Theta$ ($^{\circ}$C)',fontsize=18)
# Out:
# Text(0.5, 1.0, '$\\Theta$ ($^{\\circ}$C)')

# %% [markdown]
# ### Model vs observed comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(1,4,figsize = (16,3.3))
ket.bySeason(ax,seasons,obsvar,modvar,mv,season_titles)
fig,ax=plt.subplots(1,1,figsize=(20,.3))
ax.plot(data_CTD.dtUTC,np.ones(np.shape(data_CTD.dtUTC)),'k.')
ax.set_xlim((dt.datetime(year,1,1),dt.datetime(year,12,31)))
ax.set_title('data_CTD Timing')
ax.yaxis.set_visible(False)

# %% [markdown]
# ### Temperature-Salinity by Region

# %%
def tsplot(ax,svar,tvar):
    limsS=(0,36)
    limsT=(5,20)
    ss,tt=np.meshgrid(np.linspace(limsS[0],limsS[1],20),np.linspace(limsT[0],limsT[1],20))
    rho=gsw.rho(ss,tt,np.zeros(np.shape(ss)))
    r=ax.contour(ss,tt,rho,colors='k')
    ps=list()
    for ind, iregion in enumerate(data_CTD.Basin.unique()):
        p=ax.plot(datreg_CTD[iregion][svar], datreg_CTD[iregion][tvar],'.',
                color = colors[ind], label=iregion)
        ps.append(p[0])
    l=ax.legend(handles=ps,bbox_to_anchor=(1.01,1))
    ax.set_ylim(limsT)
    ax.set_xlim(limsS)
    ax.set_ylabel('$\Theta$ ($^{\circ}$C)')
    ax.set_xlabel('S$_A$ (g kg$^{-1}$)')
    ax.set_aspect((limsS[1]-limsS[0])/(limsT[1]-limsT[0]))
    return

# %%
fig,ax=plt.subplots(1,2,figsize=(16,3.5))
tsplot(ax[0],'SA','CT')
ax[0].set_title('Observed')
tsplot(ax[1],'mod_vosaline','mod_votemper')
ax[1].set_title('Modelled')
# Out:
# Text(0.5, 1.0, 'Modelled')

# %% [markdown]
# ### Summary table of temperature and salinity evaluation statistics

# %%
#No longer entirely accurate, should create seperate ones for each of the chlorophyll 
#comparisons and the CT SA analysis. Also should probably not log transform for the table.
tbl,tdf=et.displayStats(statsDict_CTSA[year],level='Variable',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" >Variable</th>        <th class="index_name level1" ></th>        <th class="index_name level2" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level0_row0" class="row_heading level0 row0" rowspan=16>CT</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level1_row0" class="row_heading level1 row0" >0</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level2_row0" class="row_heading level2 row0" >z < 15 m</th>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row0_col0" class="data row0 col0" >0.144905</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row0_col1" class="data row0 col1" >6619.000000</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row0_col2" class="data row0 col2" >1.091836</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row0_col3" class="data row0 col3" >0.950838</td>
#             </tr>
#             <tr>
#                                 <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level1_row1" class="row_heading level1 row1" >1</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level2_row1" class="row_heading level2 row1" >15 m < z < 22 m</th>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row1_col0" class="data row1 col0" >-0.149377</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row1_col1" class="data row1 col1" >2990.000000</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row1_col2" class="data row1 col2" >0.714967</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row1_col3" class="data row1 col3" >0.960686</td>
#             </tr>
#             <tr>
#                                 <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level1_row2" class="row_heading level1 row2" >2</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level2_row2" class="row_heading level2 row2" >z >= 22 m</th>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row2_col0" class="data row2 col0" >-0.207084</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row2_col1" class="data row2 col1" >33877.000000</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row2_col2" class="data row2 col2" >0.573705</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row2_col3" class="data row2 col3" >0.968953</td>
#             </tr>
#             <tr>
#                                 <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level1_row3" class="row_heading level1 row3" >3</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level2_row3" class="row_heading level2 row3" >z > 50 m</th>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row3_col0" class="data row3 col0" >-0.208076</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row3_col1" class="data row3 col1" >23355.000000</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row3_col2" class="data row3 col2" >0.531465</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row3_col3" class="data row3 col3" >0.971649</td>
#             </tr>
#             <tr>
#                                 <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level1_row4" class="row_heading level1 row4" >4</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level2_row4" class="row_heading level2 row4" >all</th>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row4_col0" class="data row4 col0" >-0.149540</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row4_col1" class="data row4 col1" >43486.000000</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row4_col2" class="data row4 col2" >0.687755</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row4_col3" class="data row4 col3" >0.965929</td>
#             </tr>
#             <tr>
#                                 <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level1_row5" class="row_heading level1 row5" >5</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level2_row5" class="row_heading level2 row5" >z < 15 m, DJF</th>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row5_col0" class="data row5 col0" >-0.212395</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row5_col1" class="data row5 col1" >165.000000</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row5_col2" class="data row5 col2" >0.238863</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row5_col3" class="data row5 col3" >0.529533</td>
#             </tr>
#             <tr>
#                                 <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level1_row6" class="row_heading level1 row6" >6</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level2_row6" class="row_heading level2 row6" >z < 15 m, MAM</th>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row6_col0" class="data row6 col0" >0.213620</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row6_col1" class="data row6 col1" >622.000000</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row6_col2" class="data row6 col2" >0.457542</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row6_col3" class="data row6 col3" >0.862394</td>
#             </tr>
#             <tr>
#                                 <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level1_row7" class="row_heading level1 row7" >7</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level2_row7" class="row_heading level2 row7" >z < 15 m, JJA</th>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row7_col0" class="data row7 col0" >0.464440</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row7_col1" class="data row7 col1" >2873.000000</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row7_col2" class="data row7 col2" >1.481652</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row7_col3" class="data row7 col3" >0.888637</td>
#             </tr>
#             <tr>
#                                 <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level1_row8" class="row_heading level1 row8" >8</th>
#                         <th id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4level2_row8" class="row_heading level2 row8" >z < 15 m, SON</th>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row8_col0" class="data row8 col0" >-0.212655</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row8_col1" class="data row8 col1" >2417.000000</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row8_col2" class="data row8 col2" >0.732654</td>
#                         <td id="T_2b8bb181_6bcd_11eb_a7d6_10c37b4d98e4row8_col3" class="dat

# %% [markdown]
# # Observed Chlorophyll vs Model Phytoplankton

# %%
#Setting variables for Chlorophyll.
obsvar='Chl'
modvar='mod_diatoms'

# %% [markdown]
# ## Model Diatoms vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets

# %%
statsDict_Chl={year:dict()}
statsDict_Chl[year]['Diatoms']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl[year]['Diatoms'][isub]=dict()
    var=statsDict_Chl[year]['Diatoms'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_Chl[year]['Diatoms'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row0_col0" class="data row0 col0" >-4.640422</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row0_col1" class="data row0 col1" >6565.000000</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row0_col2" class="data row0 col2" >9.935114</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row0_col3" class="data row0 col3" >0.315376</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row1_col0" class="data row1 col0" >-2.318853</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row1_col1" class="data row1 col1" >2990.000000</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row1_col2" class="data row1 col2" >4.224536</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row1_col3" class="data row1 col3" >0.310042</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row2_col0" class="data row2 col0" >-2.195682</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row2_col1" class="data row2 col1" >33877.000000</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row2_col2" class="data row2 col2" >7.585853</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row2_col3" class="data row2 col3" >0.154264</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row3_col0" class="data row3 col0" >-2.417174</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row3_col1" class="data row3 col1" >23355.000000</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row3_col2" class="data row3 col2" >8.629431</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row3_col3" class="data row3 col3" >0.160717</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row4_col0" class="data row4 col0" >-2.573698</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row4_col1" class="data row4 col1" >43432.000000</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row4_col2" class="data row4 col2" >7.812424</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row4_col3" class="data row4 col3" >0.206003</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row5_col0" class="data row5 col0" >-1.404514</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row5_col1" class="data row5 col1" >165.000000</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row5_col2" class="data row5 col2" >1.601830</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row5_col3" class="data row5 col3" >0.403005</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row6_col0" class="data row6 col0" >-3.495289</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row6_col1" class="data row6 col1" >621.000000</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row6_col2" class="data row6 col2" >7.814041</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row6_col3" class="data row6 col3" >0.365060</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row7_col0" class="data row7 col0" >-6.277819</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row7_col1" class="data row7 col1" >2857.000000</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row7_col2" class="data row7 col2" >11.806786</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row7_col3" class="data row7 col3" >0.335429</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row8_col0" class="data row8 col0" >-3.748658</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row8_col1" class="data row8 col1" >2381.000000</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row8_col2" class="data row8 col2" >9.298835</td>
#                         <td id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4row8_col3" class="data row8 col3" >0.242082</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_2b96f9e5_6bcd_11eb_bcd7_10c37b4d98e4level1_row9" class="row_heading level1 row9" >Strait o

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_diatoms'

mv=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,mv)
ax[0].set_title('Diatoms vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')   

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,mv)
ax[1].set_title('Diatoms vs Chlorophyll by Region');
ax[1].set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of model diatoms vs observed cholophyll

# %%
fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Diatoms vs Chlorophyl')
ax.set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### Model vs observed comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (18,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,mv,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Modeled Diatoms (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')   
fig,ax=plt.subplots(1,1,figsize=(20,.3))
ax.plot(data_CTD.dtUTC,np.ones(np.shape(data_CTD.dtUTC)),'k.')
ax.set_xlim((dt.datetime(year,1,1),dt.datetime(year,12,31)))
ax.set_title('data_CTD Timing')
ax.yaxis.set_visible(False)

# %% [markdown]
# ## Model Ciliates vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets.

# %%
obsvar='Chl'
modvar='mod_ciliates'

statsDict_Chl[year]['Ciliates']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl[year]['Ciliates'][isub]=dict()
    var=statsDict_Chl[year]['Ciliates'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_Chl[year]['Ciliates'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row0_col0" class="data row0 col0" >-5.170955</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row0_col1" class="data row0 col1" >6565.000000</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row0_col2" class="data row0 col2" >10.321894</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row0_col3" class="data row0 col3" >0.307433</td>
#             </tr>
#             <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row1_col0" class="data row1 col0" >-2.489627</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row1_col1" class="data row1 col1" >2990.000000</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row1_col2" class="data row1 col2" >4.406052</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row1_col3" class="data row1 col3" >0.295375</td>
#             </tr>
#             <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row2_col0" class="data row2 col0" >-2.209246</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row2_col1" class="data row2 col1" >33877.000000</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row2_col2" class="data row2 col2" >7.619439</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row2_col3" class="data row2 col3" >0.152092</td>
#             </tr>
#             <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row3_col0" class="data row3 col0" >-2.417602</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row3_col1" class="data row3 col1" >23355.000000</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row3_col2" class="data row3 col2" >8.656891</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row3_col3" class="data row3 col3" >0.158830</td>
#             </tr>
#             <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row4_col0" class="data row4 col0" >-2.676228</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row4_col1" class="data row4 col1" >43432.000000</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row4_col2" class="data row4 col2" >7.919877</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row4_col3" class="data row4 col3" >0.197295</td>
#             </tr>
#             <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row5_col0" class="data row5 col0" >-1.315252</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row5_col1" class="data row5 col1" >165.000000</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row5_col2" class="data row5 col2" >1.514406</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row5_col3" class="data row5 col3" >0.416963</td>
#             </tr>
#             <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row6_col0" class="data row6 col0" >-4.132164</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row6_col1" class="data row6 col1" >621.000000</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row6_col2" class="data row6 col2" >8.401322</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row6_col3" class="data row6 col3" >0.311604</td>
#             </tr>
#             <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row7_col0" class="data row7 col0" >-7.248745</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row7_col1" class="data row7 col1" >2857.000000</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row7_col2" class="data row7 col2" >12.389586</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row7_col3" class="data row7 col3" >0.341583</td>
#             </tr>
#             <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row8_col0" class="data row8 col0" >-3.880147</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row8_col1" class="data row8 col1" >2381.000000</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row8_col2" class="data row8 col2" >9.411115</td>
#                         <td id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4row8_col3" class="data row8 col3" >0.237804</td>
#             </tr>
#             <tr>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_2cba8552_6bcd_11eb_a057_10c37b4d98e4level1_row9" class="row_heading level1 row9" >Strait

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_ciliates'

mv=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,mv)
ax[0].set_title('Cliliates vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Model Ciliates (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')  

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,mv)
ax[1].set_title('Cliliates vs Chlorophyll by Region')
ax[1].set_ylabel('log10[Model Ciliates (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of model ciliates vs observed chlorophyll

# %%
fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Cliliates vs Chlorophyll')
ax.set_ylabel('log10[Model Ciliates (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ## Model Ciliates vs observed Chlorophyll comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (16,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,mv,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Modeled Cilliates (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')  
fig,ax=plt.subplots(1,1,figsize=(20,.3))
ax.plot(data_CTD.dtUTC,np.ones(np.shape(data_CTD.dtUTC)),'k.')
ax.set_xlim((dt.datetime(year,1,1),dt.datetime(year,12,31)))
ax.set_title('data_CTD Timing')
ax.yaxis.set_visible(False)

# %% [markdown]
# ## Model Flagellates vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets.

# %%
obsvar='Chl'
modvar='mod_flagellates'

statsDict_Chl[year]['Flagellates']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl[year]['Flagellates'][isub]=dict()
    var=statsDict_Chl[year]['Flagellates'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_Chl[year]['Flagellates'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row0_col0" class="data row0 col0" >-5.165999</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row0_col1" class="data row0 col1" >6565.000000</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row0_col2" class="data row0 col2" >10.307574</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row0_col3" class="data row0 col3" >0.307389</td>
#             </tr>
#             <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row1_col0" class="data row1 col0" >-2.494841</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row1_col1" class="data row1 col1" >2990.000000</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row1_col2" class="data row1 col2" >4.418321</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row1_col3" class="data row1 col3" >0.293612</td>
#             </tr>
#             <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row2_col0" class="data row2 col0" >-2.225541</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row2_col1" class="data row2 col1" >33877.000000</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row2_col2" class="data row2 col2" >7.628112</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row2_col3" class="data row2 col3" >0.152352</td>
#             </tr>
#             <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row3_col0" class="data row3 col0" >-2.433979</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row3_col1" class="data row3 col1" >23355.000000</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row3_col2" class="data row3 col2" >8.664879</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row3_col3" class="data row3 col3" >0.159202</td>
#             </tr>
#             <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row4_col0" class="data row4 col0" >-2.688548</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row4_col1" class="data row4 col1" >43432.000000</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row4_col2" class="data row4 col2" >7.924040</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row4_col3" class="data row4 col3" >0.197568</td>
#             </tr>
#             <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row5_col0" class="data row5 col0" >-1.195050</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row5_col1" class="data row5 col1" >165.000000</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row5_col2" class="data row5 col2" >1.395556</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row5_col3" class="data row5 col3" >0.438988</td>
#             </tr>
#             <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row6_col0" class="data row6 col0" >-4.035953</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row6_col1" class="data row6 col1" >621.000000</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row6_col2" class="data row6 col2" >8.323012</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row6_col3" class="data row6 col3" >0.312806</td>
#             </tr>
#             <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row7_col0" class="data row7 col0" >-7.341656</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row7_col1" class="data row7 col1" >2857.000000</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row7_col2" class="data row7 col2" >12.442767</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row7_col3" class="data row7 col3" >0.342711</td>
#             </tr>
#             <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row8_col0" class="data row8 col0" >-3.818177</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row8_col1" class="data row8 col1" >2381.000000</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row8_col2" class="data row8 col2" >9.310092</td>
#                         <td id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4row8_col3" class="data row8 col3" >0.240836</td>
#             </tr>
#             <tr>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_2de1fbfe_6bcd_11eb_a8f6_10c37b4d98e4level1_row9" class="row_heading level1 row9" >Strait

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_flagellates'

mv=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,mv)
ax[0].set_title('Flagellates vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')  

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,mv)
ax[1].set_title('Flagellates vs Chlorophyll by Region')
ax[1].set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of model flagellates vs observed Chlorophyll

# %%
fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Flagellates vs Chlorophyll')
ax.set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 28.0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### Model flagellates vs observed Chlorophyll comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (16,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,mv,season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Model Flagellates (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
fig,ax=plt.subplots(1,1,figsize=(20,.3))
ax.plot(data_CTD.dtUTC,np.ones(np.shape(data_CTD.dtUTC)),'k.')
ax.set_xlim((dt.datetime(year,1,1),dt.datetime(year,12,31)))
ax.set_title('data_CTD Timing')
ax.yaxis.set_visible(False)

# %% [markdown]
# ## All Model Phytoplankton vs Observed Chlorophyll
# ### Table containing evaluation statistics for relevant subsets.

# %%
obsvar='Chl'
modvar='mod_Chl'

statsDict_Chl[year]['All']=OrderedDict()
for isub in statsubs_CTD:
    statsDict_Chl[year]['All'][isub]=dict()
    var=statsDict_Chl[year]['All'][isub]
    var['N'],mmean,omean,var['Bias'],var['RMSE'],var['WSS']=et.stats(statsubs_CTD[isub].loc[:,[obsvar]], 
                                                                     statsubs_CTD[isub].loc[:,[modvar]])
tbl,tdf=et.displayStats(statsDict_Chl[year]['All'],level='Subset',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row0" class="row_heading level1 row0" >z < 15 m</th>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row0_col0" class="data row0 col0" >-3.231188</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row0_col1" class="data row0 col1" >6565.000000</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row0_col2" class="data row0 col2" >9.139909</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row0_col3" class="data row0 col3" >0.331676</td>
#             </tr>
#             <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row1" class="row_heading level1 row1" >15 m < z < 22 m</th>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row1_col0" class="data row1 col0" >-1.639804</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row1_col1" class="data row1 col1" >2990.000000</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row1_col2" class="data row1 col2" >3.835623</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row1_col3" class="data row1 col3" >0.316353</td>
#             </tr>
#             <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row2" class="row_heading level1 row2" >z >= 22 m</th>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row2_col0" class="data row2 col0" >-1.908647</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row2_col1" class="data row2 col1" >33877.000000</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row2_col2" class="data row2 col2" >7.490212</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row2_col3" class="data row2 col3" >0.144191</td>
#             </tr>
#             <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row3" class="row_heading level1 row3" >z > 50 m</th>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row3_col0" class="data row3 col0" >-2.177873</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row3_col1" class="data row3 col1" >23355.000000</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row3_col2" class="data row3 col2" >8.548942</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row3_col3" class="data row3 col3" >0.151810</td>
#             </tr>
#             <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row4" class="row_heading level1 row4" >all</th>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row4_col0" class="data row4 col0" >-2.090049</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row4_col1" class="data row4 col1" >43432.000000</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row4_col2" class="data row4 col2" >7.576323</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row4_col3" class="data row4 col3" >0.222540</td>
#             </tr>
#             <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row5" class="row_heading level1 row5" >z < 15 m, DJF</th>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row5_col0" class="data row5 col0" >-0.845807</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row5_col1" class="data row5 col1" >165.000000</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row5_col2" class="data row5 col2" >1.075314</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row5_col3" class="data row5 col3" >0.501784</td>
#             </tr>
#             <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row6" class="row_heading level1 row6" >z < 15 m, MAM</th>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row6_col0" class="data row6 col0" >-2.176170</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row6_col1" class="data row6 col1" >621.000000</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row6_col2" class="data row6 col2" >7.311994</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row6_col3" class="data row6 col3" >0.420904</td>
#             </tr>
#             <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row7" class="row_heading level1 row7" >z < 15 m, JJA</th>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row7_col0" class="data row7 col0" >-4.194283</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row7_col1" class="data row7 col1" >2857.000000</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row7_col2" class="data row7 col2" >10.710213</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row7_col3" class="data row7 col3" >0.319319</td>
#             </tr>
#             <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row8" class="row_heading level1 row8" >z < 15 m, SON</th>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row8_col0" class="data row8 col0" >-2.957140</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row8_col1" class="data row8 col1" >2381.000000</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row8_col2" class="data row8 col2" >8.786872</td>
#                         <td id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4row8_col3" class="data row8 col3" >0.247456</td>
#             </tr>
#             <tr>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_2ef4e224_6bcd_11eb_a3d2_10c37b4d98e4level1_row9" class="row_heading level1 row9" >Strait o

# %% [markdown]
# ### Comparisons by depth and region

# %%
obsvar='log_Chl'
modvar='log_mod_Chl'

mv=(-3.2,2)
fig, ax = plt.subplots(1,2,figsize = (16,7))
ps,l=ket.byDepth(ax[0],data_CTD,obsvar,modvar,mv)
ax[0].set_title('Phytoplankton vs Chlorophyll by Depth')
ax[0].set_ylabel('log10[Model Phytoplankton (mg Chl/m$^3$)]')
ax[0].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]') 

ps,l=ket.byRegion(ax[1],data_CTD,datreg_CTD,obsvar,modvar,mv)
ax[1].set_title('Phytoplankton vs Chlorophyll by Depth')
ax[1].set_ylabel('log10[Model Phytoplankton (mg Chl/m$^3$)]')
ax[1].set_xlabel('log10[Observed Clorophyll mg/m$^3$ (CTD)]')
# Out:
# Text(0.5, 0, 'log10[Observed Clorophyll mg/m$^3$ (CTD)]')

# %% [markdown]
# ### 2D Histogram of all model phytoplankton vs observed Chlorophyll

# %%
obsvar='log_Chl'
modvar='log_mod_Chl'

fig, ax = plt.subplots(1,1,figsize= (8,6))
ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
ax.set_title('Phytoplankton vs Chlorophyll by Depth')
ax.set_ylabel('log10[Model Phytoplankton (mg Chl/m$^3$)]')
ax.set_xlabel('log10[Observed Chlorophyll mg/m$^3$ (CTD)]')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-46741f885600> in <module>
#       2 modvar='log_mod_Chl'
#       3
# ----> 4 fig, ax = plt.subplots(1,1,figsize= (8,6))
#       5 ps = ket.hist2d(ax,fig,data_CTD,obsvar,modvar,(-3.2,2),fontsize=18)
#       6 ax.set_title('Phytoplankton vs Chlorophyll by Depth')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Model Chlorophyll vs observed Chlorophyll comparisons for multiple seasons

# %%
seasons=[DJF_CTD,MAM_CTD,JJA_CTD,SON_CTD]
season_titles=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']

fig, ax = plt.subplots(2,2,figsize = (16,10))
ket.bySeason_hist2d(ax,fig,seasons,obsvar,modvar,(-3.2,2),season_titles)
for i in range(2):
    for j in range(2):
        ax[i][j].set_ylabel('log10[Model phytoplankton (mg Chl/m$^3$)]')
        ax[i][j].set_xlabel('log10[Observed Chlorophyll mg/m$^3$ (CTD)]')
fig,ax=plt.subplots(1,1,figsize=(20,.3))
ax.plot(data_CTD.dtUTC,np.ones(np.shape(data_CTD.dtUTC)),'k.')
ax.set_xlim((dt.datetime(year,1,1),dt.datetime(year,12,31)))
ax.set_title('data_CTD Timing')
ax.yaxis.set_visible(False)

# %% [markdown]
# ### Summary table of evaluation statistics for Temperature, Salinity, and Chlorophyll.

# %%
tbl,tdf=et.displayStats(statsDict_Chl[year],level='Variable',suborder=list(statsubs_CTD.keys()))
tbl
# Out:
# <style  type="text/css" >
# </style><table id="T_30140934_6bcd_11eb_a202_10c37b4d98e4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Bias</th>        <th class="col_heading level1 col1" >N</th>        <th class="col_heading level1 col2" >RMSE</th>        <th class="col_heading level1 col3" >WSS</th>    </tr>    <tr>        <th class="index_name level0" >Variable</th>        <th class="index_name level1" ></th>        <th class="index_name level2" >Subset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level0_row0" class="row_heading level0 row0" rowspan=16>All</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level1_row0" class="row_heading level1 row0" >0</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level2_row0" class="row_heading level2 row0" >z < 15 m</th>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row0_col0" class="data row0 col0" >-3.231188</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row0_col1" class="data row0 col1" >6565.000000</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row0_col2" class="data row0 col2" >9.139909</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row0_col3" class="data row0 col3" >0.331676</td>
#             </tr>
#             <tr>
#                                 <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level1_row1" class="row_heading level1 row1" >1</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level2_row1" class="row_heading level2 row1" >15 m < z < 22 m</th>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row1_col0" class="data row1 col0" >-1.639804</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row1_col1" class="data row1 col1" >2990.000000</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row1_col2" class="data row1 col2" >3.835623</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row1_col3" class="data row1 col3" >0.316353</td>
#             </tr>
#             <tr>
#                                 <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level1_row2" class="row_heading level1 row2" >2</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level2_row2" class="row_heading level2 row2" >z >= 22 m</th>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row2_col0" class="data row2 col0" >-1.908647</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row2_col1" class="data row2 col1" >33877.000000</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row2_col2" class="data row2 col2" >7.490212</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row2_col3" class="data row2 col3" >0.144191</td>
#             </tr>
#             <tr>
#                                 <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level1_row3" class="row_heading level1 row3" >3</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level2_row3" class="row_heading level2 row3" >z > 50 m</th>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row3_col0" class="data row3 col0" >-2.177873</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row3_col1" class="data row3 col1" >23355.000000</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row3_col2" class="data row3 col2" >8.548942</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row3_col3" class="data row3 col3" >0.151810</td>
#             </tr>
#             <tr>
#                                 <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level1_row4" class="row_heading level1 row4" >4</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level2_row4" class="row_heading level2 row4" >all</th>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row4_col0" class="data row4 col0" >-2.090049</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row4_col1" class="data row4 col1" >43432.000000</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row4_col2" class="data row4 col2" >7.576323</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row4_col3" class="data row4 col3" >0.222540</td>
#             </tr>
#             <tr>
#                                 <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level1_row5" class="row_heading level1 row5" >5</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level2_row5" class="row_heading level2 row5" >z < 15 m, DJF</th>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row5_col0" class="data row5 col0" >-0.845807</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row5_col1" class="data row5 col1" >165.000000</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row5_col2" class="data row5 col2" >1.075314</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row5_col3" class="data row5 col3" >0.501784</td>
#             </tr>
#             <tr>
#                                 <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level1_row6" class="row_heading level1 row6" >6</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level2_row6" class="row_heading level2 row6" >z < 15 m, MAM</th>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row6_col0" class="data row6 col0" >-2.176170</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row6_col1" class="data row6 col1" >621.000000</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row6_col2" class="data row6 col2" >7.311994</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row6_col3" class="data row6 col3" >0.420904</td>
#             </tr>
#             <tr>
#                                 <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level1_row7" class="row_heading level1 row7" >7</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level2_row7" class="row_heading level2 row7" >z < 15 m, JJA</th>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row7_col0" class="data row7 col0" >-4.194283</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row7_col1" class="data row7 col1" >2857.000000</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row7_col2" class="data row7 col2" >10.710213</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row7_col3" class="data row7 col3" >0.319319</td>
#             </tr>
#             <tr>
#                                 <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level1_row8" class="row_heading level1 row8" >8</th>
#                         <th id="T_30140934_6bcd_11eb_a202_10c37b4d98e4level2_row8" class="row_heading level2 row8" >z < 15 m, SON</th>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row8_col0" class="data row8 col0" >-2.957140</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row8_col1" class="data row8 col1" >2381.000000</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row8_col2" class="data row8 col2" >8.786872</td>
#                         <td id="T_30140934_6bcd_11eb_a202_10c37b4d98e4row8_col3" class
